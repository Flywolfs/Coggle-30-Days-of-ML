# %%
import pandas as pd
import re
import random
import tarfile
import requests
import numpy as np
import paddle
from paddle.nn import Embedding
import paddle.nn.functional as F
from paddle.nn import LSTM, Embedding, Dropout, Linear
import paddle.fluid as fluid
train_data = pd.read_csv('train.csv', sep='\t', header=None)
test_data = pd.read_csv('test.csv', sep='\t', header=None)
train_data.columns = ["text","label"]
test_data.columns = ["text"]

# %%
import jieba
def load_data(data,train=True):
    data_set = []
    if train:
        for i in range(0,len(data)):
            text = data.iloc[i]["text"]
            label = data.iloc[i]["label"]
            sentence = jieba.cut(text, cut_all=False)
            data_set.append((" ".join(sentence), label))
    else:
        for i in range(0,len(data)):
            text = data.iloc[i]["text"]
            sentence = jieba.cut(text, cut_all=False)
            data_set.append((" ".join(sentence)))
    return data_set

# %%
train_corpus = load_data(train_data)

# %%
test_corpus = load_data(test_data,train=False)

# %%
df_test = pd.DataFrame(train_corpus)

# %%
df_test[0].apply(len).describe()
# Out:
# count    12100.000000
# mean         9.006281
# std          3.160494
# min          2.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.000000
# max         31.000000
# Name: 0, dtype: float64

# %%
word2id_dict = dict()

# %%
#使用开源的word2vec词向量：来源https://github.com/Flywolfs/Chinese-Word-Vectors
word2vec_path = "word2vec\\sgns.zhihu.word\\sgns.zhihu.word"
zhi_vec_depth = 300
import numpy as np
zhihu_w2v = {}
with open(word2vec_path,"r",encoding="utf-8") as f:
    for line in f.readlines()[1:]:
        line = line.rstrip()
        seps = line.split(" ")
        word = seps[0]
        vec = seps[1:]
        zhihu_w2v[seps[0]] = np.array(vec,dtype=float)

# %%
word2id_dict['[oov]'] = 0
word2id_dict['[pad]'] = 1
index = 2
for word in zhihu_w2v:
    word2id_dict[word] = index
    index += 1

# %%
oov_embedding_init = np.random.uniform(low=-0.1, high=0.1, size=300).tolist()
pad_embeeding_init = np.random.uniform(low=-0.1, high=0.1, size=300).tolist()

# %%
embedding_init = [oov_embedding_init,pad_embeeding_init]
for word in word2id_dict:
    if word != "[oov]" and word != "[pad]":
        embedding_init.append(zhihu_w2v[word].tolist())

# %%
embedding_init = np.array(embedding_init,dtype="float32")

# %%
labels = train_data["label"].unique().tolist()
label_dict = {}
for i in range(len(labels)):
    label_dict[labels[i]] = i

# %%
label_dict
# Out:
# {'Travel-Query': 0,
#  'Music-Play': 1,
#  'FilmTele-Play': 2,
#  'Video-Play': 3,
#  'Radio-Listen': 4,
#  'HomeAppliance-Control': 5,
#  'Weather-Query': 6,
#  'Alarm-Update': 7,
#  'Calendar-Query': 8,
#  'TVProgram-Play': 9,
#  'Audio-Play': 10,
#  'Other': 11}

# %%
def convert_corpus_to_id(corpus, word2id_dict, train=True):
    data_set = []
    if train:
        for sentence, sentence_label in corpus:
            label = label_dict.get(sentence_label, -1)
            # 将句子中的词逐个替换成id，如果句子中的词不在词表内，则替换成oov
            # 这里需要注意，一般来说我们可能需要查看一下test-set中，句子oov的比例，
            # 如果存在过多oov的情况，那就说明我们的训练数据不足或者切分存在巨大偏差，需要调整
            sentence = [word2id_dict[word] if word in word2id_dict \
                        else word2id_dict['[oov]'] for word in sentence.split(" ")]    
            data_set.append((sentence, label))
    else:
        for sentence in corpus:
            # 将句子中的词逐个替换成id，如果句子中的词不在词表内，则替换成oov
            # 这里需要注意，一般来说我们可能需要查看一下test-set中，句子oov的比例，
            # 如果存在过多oov的情况，那就说明我们的训练数据不足或者切分存在巨大偏差，需要调整
            sentence = [word2id_dict[word] if word in word2id_dict \
                        else word2id_dict['[oov]'] for word in sentence.split(" ")]    
            data_set.append((sentence))
    return data_set

# %%
train_corpus = convert_corpus_to_id(train_corpus, word2id_dict)

# %%
test_corpus =  convert_corpus_to_id(test_corpus, word2id_dict,train=False)

# %%
def build_batch(word2id_dict, corpus, batch_size, epoch_num, max_seq_len, shuffle = True, drop_last = True, train=True):

    # 模型将会接受的两个输入：
    # 1. 一个形状为[batch_size, max_seq_len]的张量，sentence_batch，代表了一个mini-batch的句子。
    # 2. 一个形状为[batch_size, 1]的张量，sentence_label_batch，每个元素都是非0即1，代表了每个句子的情感类别（正向或者负向）
    sentence_batch = []
    sentence_label_batch = []
    if train:
        for _ in range(epoch_num): 

            #每个epoch前都shuffle一下数据，有助于提高模型训练的效果
            #但是对于预测任务，不要做数据shuffle
            if shuffle:
                random.shuffle(corpus)

            for sentence, sentence_label in corpus:
                sentence_sample = sentence[:min(max_seq_len, len(sentence))]
                if len(sentence_sample) < max_seq_len:
                    for _ in range(max_seq_len - len(sentence_sample)):
                        sentence_sample.append(word2id_dict['[pad]'])


                sentence_sample = [[word_id] for word_id in sentence_sample]

                sentence_batch.append(sentence_sample)
                sentence_label_batch.append([sentence_label])

                if len(sentence_batch) == batch_size:
                    yield np.array(sentence_batch).astype("int64"), np.array(sentence_label_batch).astype("int64")
                    sentence_batch = []
                    sentence_label_batch = []
        if not drop_last and len(sentence_batch) > 0:
            yield np.array(sentence_batch).astype("int64"), np.array(sentence_label_batch).astype("int64")
    else:
        for sentence in corpus:
            sentence_sample = sentence[:min(max_seq_len, len(sentence))]
            if len(sentence_sample) < max_seq_len:
                for _ in range(max_seq_len - len(sentence_sample)):
                    sentence_sample.append(word2id_dict['[pad]'])


            sentence_sample = [[word_id] for word_id in sentence_sample]

            sentence_batch.append(sentence_sample)

            if len(sentence_batch) == batch_size:
                yield np.array(sentence_batch).astype("int64")
                sentence_batch = []
                sentence_label_batch = []
        if len(sentence_batch) > 0:
            yield np.array(sentence_batch).astype("int64")

# %%
import paddle.fluid as fluid
class IntentClassifier(paddle.nn.Layer):
    
    def __init__(self, hidden_size, vocab_size, embedding_size, class_num=12, num_steps=128, num_layers=1, init_scale=0.1, dropout_rate=None):
        
        # 参数含义如下：
        # 1.hidden_size，表示embedding-size，hidden和cell向量的维度
        # 2.vocab_size，模型可以考虑的词表大小
        # 3.embedding_size，表示词向量的维度
        # 4.class_num，情感类型个数，可以是2分类，也可以是多分类
        # 5.num_steps，表示这个情感分析模型最大可以考虑的句子长度
        # 6.num_layers，表示网络的层数
        # 7.dropout_rate，表示使用dropout过程中失活的神经元比例
        # 8.init_scale，表示网络内部的参数的初始化范围,长短时记忆网络内部用了很多Tanh，Sigmoid等激活函数，\
        # 这些函数对数值精度非常敏感，因此我们一般只使用比较小的初始化范围，以保证效果
        super(IntentClassifier, self).__init__()
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.embedding_size = embedding_size
        self.class_num = class_num
        self.num_steps = num_steps
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate
        self.init_scale = init_scale
       
        # 声明一个LSTM模型，用来把每个句子抽象成向量
        self.simple_lstm_rnn = paddle.nn.LSTM(input_size=hidden_size, hidden_size=hidden_size, num_layers=num_layers)

        # 声明一个embedding层，用来把句子中的每个词转换为向量
        self.embedding = paddle.nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_size, sparse=False, 
                                    weight_attr=fluid.initializer.NumpyArrayInitializer(embedding_init))
        
#         self.embedding = paddle.nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_size, sparse=False, 
#                                     weight_attr=paddle.ParamAttr(initializer=paddle.nn.initializer.Uniform(low=-init_scale, high=init_scale)))
        
        # 声明使用上述语义向量映射到具体类别时所需要使用的线性层
        self.cls_fc = paddle.nn.Linear(in_features=self.hidden_size, out_features=self.class_num, 
                             weight_attr=None, bias_attr=None)
        
        # 一般在获取单词的embedding后，会使用dropout层，防止过拟合，提升模型泛化能力
        self.dropout_layer = paddle.nn.Dropout(p=self.dropout_rate, mode='upscale_in_train')

    # forwad函数即为模型前向计算的函数，它有两个输入，分别为：
    # input为输入的训练文本，其shape为[batch_size, max_seq_len]
    # label训练文本对应的情感标签，其shape维[batch_size, 1]
    def forward(self, inputs):
        # 获取输入数据的batch_size
        batch_size = inputs.shape[0]

        # 本实验默认使用1层的LSTM，首先我们需要定义LSTM的初始hidden和cell，这里我们使用0来初始化这个序列的记忆
        init_hidden_data = np.zeros(
            (self.num_layers, batch_size, self.hidden_size), dtype='float32')
        init_cell_data = np.zeros(
            (self.num_layers, batch_size, self.hidden_size), dtype='float32')

        # 将这些初始记忆转换为飞桨可计算的向量，并且设置stop_gradient=True，避免这些向量被更新，从而影响训练效果
        init_hidden = paddle.to_tensor(init_hidden_data)
        init_hidden.stop_gradient = True
        init_cell = paddle.to_tensor(init_cell_data)
        init_cell.stop_gradient = True

        # 对应以上第2步，将输入的句子的mini-batch转换为词向量表示，转换后输入数据shape为[batch_size, max_seq_len, embedding_size]
        x_emb = self.embedding(inputs)
        x_emb = paddle.reshape(x_emb, shape=[-1, self.num_steps, self.embedding_size])
        # 在获取的词向量后添加dropout层
        if self.dropout_rate is not None and self.dropout_rate > 0.0:
            x_emb = self.dropout_layer(x_emb)
        
        # 对应以上第3步，使用LSTM网络，把每个句子转换为语义向量
        # 返回的last_hidden即为最后一个时间步的输出，其shape为[self.num_layers, batch_size, hidden_size]
        rnn_out, (last_hidden, last_cell) = self.simple_lstm_rnn(x_emb, (init_hidden, init_cell))
        # 提取最后一层隐状态作为文本的语义向量，其shape为[batch_size, hidden_size]
        last_hidden = paddle.reshape(last_hidden[-1], shape=[-1, self.hidden_size])

        # 对应以上第4步，将每个句子的向量表示映射到具体的情感类别上, logits的维度为[batch_size, 2]
        logits = self.cls_fc(last_hidden)
        
        return logits

# %%
# 定义训练参数
epoch_num = 50
batch_size = 128 

learning_rate = 0.0005
dropout_rate = 0.1
num_layers = 1
hidden_size = 300
embedding_size = 300
max_seq_len =  32
vocab_size = len(word2id_dict)

# %%
# 检测是否可以使用GPU，如果可以优先使用GPU
use_gpu = True if paddle.get_device().startswith("gpu") else False
if use_gpu:
    paddle.set_device('gpu:0')
intent_clf = IntentClassifier(hidden_size, vocab_size, embedding_size,  num_steps=max_seq_len, num_layers=num_layers, dropout_rate=dropout_rate)
optimizer = paddle.optimizer.Adam(learning_rate=learning_rate, beta1=0.9, beta2=0.999, parameters= intent_clf.parameters())
losses = []
steps = []
def train(model):
    # 开启模型训练模式
    model.train()
    
    # 建立训练数据生成器，每次迭代生成一个batch，每个batch包含训练文本和文本对应的情感标签
    # word2id_dict 词典, train_corpus 训练数据的向量表示, batch_size 每个批的大小, epoch_num 训练的次数, max_seq_len最大输入的长度
    train_loader = build_batch(word2id_dict, train_corpus, batch_size, epoch_num, max_seq_len)
    #step:迭代的次数
    for step, (sentences, labels) in enumerate(train_loader):
        # 获取数据，并将张量转换为Tensor类型
        sentences = paddle.to_tensor(sentences)
        labels = paddle.to_tensor(labels)
        one_hot_label = fluid.layers.one_hot(input=labels, depth=12)
        logits = model(sentences)
        #print(labels, "--->", logits, "--->", one_hot_label)

        # 计算损失
        loss = F.cross_entropy(input=logits, label=one_hot_label, soft_label=True)
        loss = paddle.mean(loss)
        
        # 后向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 清除梯度
        optimizer.clear_grad()
        # 记录当前步骤的loss变化情况
        losses.append(loss.numpy()[0])
        steps.append(step)
        # 打印当前loss数值
        print("step %d, loss %.3f" % (step, loss.numpy()[0]))
#训练模型
train(intent_clf)
# Out:
# step 0, loss 2.490
# step 1, loss 2.476
# step 2, loss 2.456
# step 3, loss 2.458
# step 4, loss 2.435
# step 5, loss 2.419
# step 6, loss 2.388
# step 7, loss 2.400
# step 8, loss 2.409
# step 9, loss 2.375
# step 10, loss 2.376
# step 11, loss 2.385
# step 12, loss 2.345
# step 13, loss 2.359
# step 14, loss 2.446
# step 15, loss 2.354
# step 16, loss 2.318
# step 17, loss 2.426
# step 18, loss 2.283
# step 19, loss 2.365
# step 20, loss 2.327
# step 21, loss 2.373
# step 22, loss 2.336
# step 23, loss 2.370
# step 24, loss 2.355
# step 25, loss 2.368
# step 26, loss 2.305
# step 27, loss 2.369
# step 28, loss 2.376
# step 29, loss 2.345
# step 30, loss 2.326
# step 31, loss 2.345
# step 32, loss 2.388
# step 33, loss 2.387
# step 34, loss 2.340
# step 35, loss 2.390
# step 36, loss 2.336
# step 37, loss 2.437
# step 38, loss 2.357
# step 39, loss 2.343
# step 40, loss 2.399
# step 41, loss 2.381
# step 42, loss 2.345
# step 43, loss 2.326
# step 44, loss 2.306
# step 45, loss 2.379
# step 46, loss 2.357
# step 47, loss 2.402
# step 48, loss 2.411
# step 49, loss 2.429
# step 50, loss 2.414
# step 51, loss 2.274
# step 52, loss 2.431
# step 53, loss 2.388
# step 54, loss 2.334
# step 55, loss 2.346
# step 56, loss 2.399
# step 57, loss 2.341
# step 58, loss 2.331
# step 59, loss 2.395
# step 60, loss 2.362
# step 61, loss 2.353
# step 62, loss 2.360
# step 63, loss 2.325
# step 64, loss 2.313
# step 65, loss 2.363
# step 66, loss 2.348
# step 67, loss 2.343
# step 68, loss 2.348
# step 69, loss 2.321
# step 70, loss 2.324
# step 71, loss 2.380
# step 72, loss 2.350
# step 73, loss 2.384
# step 74, loss 2.321
# step 75, loss 2.337
# step 76, loss 2.358
# step 77, loss 2.353
# step 78, loss 2.345
# step 79, loss 2.305
# step 80, loss 2.363
# step 81, loss 2.316
# step 82, loss 2.337
# step 83, loss 2.334
# step 84, loss 2.326
# step 85, loss 2.428
# step 86, loss 2.344
# step 87, loss 2.349
# step 88, loss 2.342
# step 89, loss 2.327
# step 90, loss 2.336
# step 91, loss 2.407
# step 92, loss 2.392
# step 93, loss 2.359
# step 94, loss 2.393
# step 95, loss 2.395
# step 96, loss 2.336
# step 97, loss 2.319
# step 98, loss 2.328
# step 99, loss 2.410
# step 100, loss 2.379
# step 101, loss 2.375
# step 102, loss 2.335
# step 103, loss 2.371
# step 104, loss 2.393
# step 105, loss 2.374
# step 106, loss 2.345
# step 107, loss 2.319
# step 108, loss 2.360
# step 109, loss 2.403
# step 110, loss 2.326
# step 111, loss 2.372
# step 112, loss 2.387
# step 113, loss 2.351
# step 114, loss 2.345
# step 115, loss 2.368
# step 116, loss 2.374
# step 117, loss 2.379
# step 118, loss 2.325
# step 119, loss 2.311
# step 120, loss 2.354
# step 121, loss 2.343
# step 122, loss 2.296
# step 123, loss 2.377
# step 124, loss 2.345
# step 125, loss 2.421
# step 126, loss 2.373
# step 127, loss 2.287
# step 128, loss 2.390
# step 129, loss 2.306
# step 130, loss 2.360
# step 131, loss 2.340
# step 132, loss 2.318
# step 133, loss 2.297
# step 134, loss 2.350
# step 135, loss 2.345
# step 136, loss 2.420
# step 137, loss 2.300
# step 138, loss 2.257
# step 139, loss 2.351
# step 140, loss 2.348
# step 141, loss 2.320
# step 142, loss 2.330
# step 143, loss 2.296
# step 144, loss 2.408
# step 145, loss 2.372
# step 146, loss 2.410
# step 147, loss 2.352
# step 148, loss 2.381
# step 149, loss 2.294
# step 150, loss 2.379
# step 151, loss 2.379
# step 152, loss 2.379
# step 153, loss 2.319
# step 154, loss 2.459
# step 155, loss 2.341
# step 156, loss 2.342
# step 157, loss 2.415
# step 158, loss 2.340
# step 159, loss 2.363
# step 160, loss 2.347
# step 161, loss 2.377
# step 162, loss 2.352
# step 163, loss 2.344
# step 164, loss 2.375
# step 165, loss 2.383
# step 166, loss 2.343
# step 167, loss 2.370
# step 168, loss 2.379
# step 169, loss 2.365
# step 170, loss 2.375
# step 171, loss 2.374
# step 172, loss 2.383
# step 173, loss 2.322
# step 174, loss 2.346
# step 175, loss 2.355
# step 176, loss 2.329
# step 177, loss 2.361
# step 178, loss 2.310
# step 179, loss 2.366
# step 180, loss 2.402
# step 181, loss 2.360
# step 182, loss 2.380
# step 183, loss 2.399
# step 184, loss 2.378
# step 185, loss 2.340
# step 186, loss 2.305
# step 187, loss 2.334
# step 188, loss 2.295
# step 189, loss 2.356
# step 190, loss 2.407
# step 191, loss 2.324
# step 192, loss 2.375
# step 193, loss 2.332
# step 194, loss 2.320
# step 195, loss 2.321
# step 196, loss 2.382
# step 197, loss 2.369
# step 198, loss 2.309
# step 199, loss 2.333
# step 200, loss 2.360
# step 201, loss 2.329
# step 202, loss 2.401
# step 203, loss 2.316
# step 204, loss 2.414
# step 205, loss 2.365
# step 206, loss 2.382
# step 207, loss 2.373
# step 208, loss 2.336
# step 209, loss 2.374
# step 210, loss 2.342
# step 211, loss 2.403
# step 212, loss 2.329
# step 213, loss 2.306
# step 214, loss 2.336
# step 215, loss 2.341
# step 216, loss 2.381
# step 217, loss 2.303
# step 218, loss 2.327
# step 219, loss 2.407
# step 220, loss 2.343
# step 221, loss 2.344
# step 222, loss 2.421
# step 223, loss 2.406
# step 224, loss 2.352
# step 225, loss 2.329
# step 226, loss 2.306
# step 227, loss 2.394
# step 228, loss 2.385
# step 229, loss 2.363
# step 230, loss 2.347
# step 231, loss 2.320
# step 232, loss 2.387
# step 233, loss 2.333
# step 234, loss 2.335
# step 235, loss 2.352
# step 236, loss 2.301
# step 237, loss 2.383
# step 238, loss 2.369
# step 239, loss 2.338
# step 240, loss 2.395
# step 241, loss 2.341
# step 242, loss 2.333
# step 243, loss 2.381
# step 244, loss 2.305
# step 245, loss 2.376
# step 246, loss 2.384
# step 247, loss 2.396
# step 248, loss 2.384
# step 249, loss 2.271
# step 250, loss 2.386
# step 251, loss 2.347
# step 252, loss 2.322
# step 253, loss 2.288
# step 254, loss 2.381
# step 255, loss 2.338
# step 256, loss 2.372
# step 257, loss 2.366
# step 258, loss 2.355
# step 259, loss 2.399
# step 260, loss 2.375
# step 261, loss 2.374
# step 262, loss 2.383
# step 263, loss 2.342
# step 264, loss 2.411
# step 265, loss 2.361
# step 266, loss 2.394
# step 267, loss 2.315
# step 268, loss 2.335
# step 269, loss 2.332
# step 270, loss 2.391
# step 271, loss 2.354
# step 272, loss 2.318
# step 273, loss 2.341
# step 274, loss 2.387
# step 275, loss 2.326
# step 276, loss 2.346
# step 277, loss 2.311
# step 278, loss 2.365
# step 279, loss 2.313
# step 280, loss 2.375
# step 281, loss 2.348
# step 282, loss 2.382
# step 283, loss 2.381
# step 284, loss 2.351
# step 285, loss 2.296
# step 286, loss 2.409
# step 287, loss 2.424
# step 288, loss 2.380
# step 289, loss 2.337
# step 290, loss 2.320
# step 291, loss 2.343
# step 292, loss 2.301
# step 293, loss 2.345
# step 294, loss 2.321
# step 295, loss 2.438
# step 296, loss 2.353
# step 297, loss 2.355
# step 298, loss 2.358
# step 299, loss 2.328
# step 300, loss 2.326
# step 301, loss 2.365
# step 302, loss 2.396
# step 303, loss 2.400
# step 304, loss 2.400
# step 305, loss 2.359
# step 306, loss 2.351
# step 307, loss 2.374
# step 308, loss 2.377
# step 309, loss 2.408
# step 310, loss 2.320
# step 311, loss 2.366
# step 312, loss 2.392
# step 313, loss 2.397
# step 314, loss 2.333
# step 315, loss 2.371
# step 316, loss 2.376
# step 317, loss 2.325
# step 318, loss 2.371
# step 319, loss 2.317
# step 320, loss 2.276
# step 321, loss 2.357
# step 322, loss 2.338
# step 323, loss 2.323
# step 324, loss 2.407
# step 325, loss 2.344
# step 326, loss 2.352
# step 327, loss 2.355
# step 328, loss 2.375
# step 329, loss 2.333
# step 330, loss 2.386
# step 331, loss 2.299
# step 332, loss 2.334
# step 333, loss 2.305
# step 334, loss 2.334
# step 335, loss 2.404
# step 336, loss 2.362
# step 337, loss 2.315
# step 338, loss 2.335
# step 339, loss 2.337
# step 340, loss 2.412
# step 341, loss 2.338
# step 342, loss 2.348
# step 343, loss 2.376
# step 344, loss 2.419
# step 345, loss 2.443
# step 346, loss 2.304
# step 347, loss 2.354
# step 348, loss 2.312
# step 349, loss 2.290
# step 350, loss 2.389
# step 351, loss 2.336
# step 352, loss 2.284
# step 353, loss 2.405
# step 354, loss 2.341
# step 355, loss 2.330
# step 356, loss 2.342
# step 357, loss 2.354
# step 358, loss 2.386
# step 359, loss 2.350
# step 360, loss 2.400
# step 361, loss 2.300
# step 362, loss 2.363
# step 363, loss 2.404
# step 364, loss 2.279
# step 365, loss 2.399
# step 366, loss 2.328
# step 367, loss 2.314
# step 368, loss 2.337
# step 369, loss 2.352
# step 370, loss 2.314
# step 371, loss 2.405
# step 372, loss 2.362
# step 373, loss 2.315
# step 374, loss 2.397
# step 375, loss 2.313
# step 376, loss 2.403
# step 377, loss 2.357
# step 378, loss 2.349
# step 379, loss 2.406
# step 380, loss 2.335
# step 381, loss 2.378
# step 382, loss 2.344
# step 383, loss 2.350
# step 384, loss 2.326
# step 385, loss 2.400
# step 386, loss 2.313
# step 387, loss 2.308
# step 388, loss 2.376
# step 389, loss 2.302
# step 390, loss 2.395
# step 391, loss 2.321
# step 392, loss 2.336
# step 393, loss 2.343
# step 394, loss 2.361
# step 395, loss 2.286
# step 396, loss 2.347
# step 397, loss 2.382
# step 398, loss 2.305
# step 399, loss 2.373
# step 400, loss 2.379
# step 401, loss 2.427
# step 402, loss 2.445
# step 403, loss 2.292
# step 404, loss 2.346
# step 405, loss 2.456
# step 406, loss 2.355
# step 407, loss 2.310
# step 408, loss 2.376
# step 409, loss 2.335
# step 410, loss 2.284
# step 411, loss 2.345
# step 412, loss 2.353
# step 413, loss 2.365
# step 414, loss 2.349
# step 415, loss 2.383
# step 416, loss 2.420
# step 417, loss 2.343
# step 418, loss 2.418
# step 419, loss 2.396
# step 420, loss 2.391
# step 421, loss 2.418
# step 422, loss 2.335
# step 423, loss 2.357
# step 424, loss 2.365
# step 425, loss 2.360
# step 426, loss 2.332
# step 427, loss 2.344
# step 428, loss 2.322
# step 429, loss 2.372
# step 430, loss 2.371
# step 431, loss 2.344
# step 432, loss 2.338
# step 433, loss 2.412
# step 434, loss 2.388
# step 435, loss 2.323
# step 436, loss 2.325
# step 437, loss 2.420
# step 438, loss 2.302
# step 439, loss 2.363
# step 440, loss 2.372
# step 441, loss 2.254
# step 442, loss 2.358
# step 443, loss 2.292
# step 444, loss 2.267
# step 445, loss 2.363
# step 446, loss 2.423
# step 447, loss 2.307
# step 448, loss 2.369
# step 449, loss 2.294
# step 450, loss 2.320
# step 451, loss 2.407
# step 452, loss 2.278
# step 453, loss 2.288
# step 454, loss 2.485
# step 455, loss 2.326
# step 456, loss 2.330
# step 457, loss 2.322
# step 458, loss 2.390
# step 459, loss 2.296
# step 460, loss 2.386
# step 461, loss 2.366
# step 462, loss 2.376
# step 463, loss 2.437
# step 464, loss 2.356
# step 465, loss 2.350
# step 466, loss 2.341
# step 467, loss 2.379
# step 468, loss 2.357
# step 469, loss 2.353
# step 470, loss 2.277
# step 471, loss 2.363
# step 472, loss 2.425
# step 473, loss 2.311
# step 474, loss 2.319
# step 475, loss 2.327
# step 476, loss 2.324
# step 477, loss 2.342
# step 478, loss 2.348
# step 479, loss 2.323
# step 480, loss 2.421
# step 481, loss 2.364
# step 482, loss 2.357
# step 483, loss 2.403
# step 484, loss 2.343
# step 485, loss 2.386
# step 486, loss 2.346
# step 487, loss 2.321
# step 488, loss 2.438
# step 489, loss 2.367
# step 490, loss 2.341
# step 491, loss 2.341
# step 492, loss 2.378
# step 493, loss 2.386
# step 494, loss 2.370
# step 495, loss 2.308
# step 496, loss 2.334
# step 497, loss 2.376
# step 498, loss 2.406
# step 499, loss 2.275
# step 500, loss 2.346
# step 501, loss 2.311
# step 502, loss 2.358
# step 503, loss 2.367
# step 504, loss 2.361
# step 505, loss 2.359
# step 506, loss 2.355
# step 507, loss 2.300
# step 508, loss 2.402
# step 509, loss 2.388
# step 510, loss 2.356
# step 511, loss 2.363
# step 512, loss 2.421
# step 513, loss 2.346
# step 514, loss 2.415
# step 515, loss 2.381
# step 516, loss 2.334
# step 517, loss 2.382
# step 518, loss 2.322
# step 519, loss 2.373
# step 520, loss 2.355
# step 521, loss 2.336
# step 522, loss 2.386
# step 523, loss 2.322
# step 524, loss 2.343
# step 525, loss 2.365
# step 526, loss 2.361
# step 527, loss 2.406
# step 528, loss 2.399
# step 529, loss 2.379
# step 530, loss 2.371
# step 531, loss 2.323
# step 532, loss 2.296
# step 533, loss 2.342
# step 534, loss 2.351
# step 535, loss 2.337
# step 536, loss 2.324
# step 537, loss 2.378
# step 538, loss 2.364
# step 539, loss 2.388
# step 540, loss 2.433
# step 541, loss 2.365
# step 542, loss 2.339
# step 543, loss 2.360
# step 544, loss 2.385
# step 545, loss 2.325
# step 546, loss 2.290
# step 547, loss 2.299
# step 548, loss 2.307
# step 549, loss 2.374
# step 550, loss 2.296
# step 551, loss 2.295
# step 552, loss 2.357
# step 553, loss 2.311
# step 554, loss 2.308
# step 555, loss 2.356
# step 556, loss 2.399
# step 557, loss 2.335
# step 558, loss 2.463
# step 559, loss 2.357
# step 560, loss 2.342
# step 561, loss 2.289
# step 562, loss 2.342
# step 563, loss 2.402
# step 564, loss 2.330
# step 565, loss 2.344
# step 566, loss 2.340
# step 567, loss 2.296
# step 568, loss 2.311
# step 569, loss 2.432
# step 570, loss 2.305
# step 571, loss 2.348
# step 572, loss 2.427
# step 573, loss 2.284
# step 574, loss 2.355
# step 575, loss 2.321
# step 576, loss 2.354
# step 577, loss 2.410
# step 578, loss 2.374
# step 579, loss 2.315
# step 580, loss 2.349
# step 581, loss 2.342
# step 582, loss 2.407
# step 583, loss 2.360
# step 584, loss 2.442
# step 585, loss 2.385
# step 586, loss 2.436
# step 587, loss 2.367
# step 588, loss 2.357
# step 589, loss 2.292
# step 590, loss 2.338
# step 591, loss 2.404
# step 592, loss 2.341
# step 593, loss 2.342
# step 594, loss 2.306
# step 595, loss 2.336
# step 596, loss 2.345
# step 597, loss 2.316
# step 598, loss 2.336
# step 599, loss 2.362
# step 600, loss 2.325
# step 601, loss 2.314
# step 602, loss 2.380
# step 603, loss 2.395
# step 604, loss 2.305
# step 605, loss 2.356
# step 606, loss 2.364
# step 607, loss 2.381
# step 608, loss 2.407
# step 609, loss 2.340
# step 610, loss 2.345
# step 611, loss 2.352
# step 612, loss 2.386
# step 613, loss 2.331
# step 614, loss 2.327
# step 615, loss 2.402
# step 616, loss 2.278
# step 617, loss 2.333
# step 618, loss 2.300
# step 619, loss 2.331
# step 620, loss 2.461
# step 621, loss 2.338
# step 622, loss 2.314
# step 623, loss 2.295
# step 624, loss 2.354
# step 625, loss 2.448
# step 626, loss 2.336
# step 627, loss 2.333
# step 628, loss 2.266
# step 629, loss 2.391
# step 630, loss 2.284
# step 631, loss 2.373
# step 632, loss 2.398
# step 633, loss 2.376
# step 634, loss 2.339
# step 635, loss 2.396
# step 636, loss 2.365
# step 637, loss 2.398
# step 638, loss 2.330
# step 639, loss 2.387
# step 640, loss 2.397
# step 641, loss 2.359
# step 642, loss 2.483
# step 643, loss 2.351
# step 644, loss 2.353
# step 645, loss 2.326
# step 646, loss 2.382
# step 647, loss 2.319
# step 648, loss 2.326
# step 649, loss 2.367
# step 650, loss 2.331
# step 651, loss 2.341
# step 652, loss 2.352
# step 653, loss 2.291
# step 654, loss 2.315
# step 655, loss 2.317
# step 656, loss 2.364
# step 657, loss 2.399
# step 658, loss 2.321
# step 659, loss 2.398
# step 660, loss 2.363
# step 661, loss 2.330
# step 662, loss 2.336
# step 663, loss 2.350
# step 664, loss 2.329
# step 665, loss 2.291
# step 666, loss 2.348
# step 667, loss 2.316
# step 668, loss 2.356
# step 669, loss 2.375
# step 670, loss 2.334
# step 671, loss 2.350
# step 672, loss 2.391
# step 673, loss 2.474
# step 674, loss 2.361
# step 675, loss 2.295
# step 676, loss 2.411
# step 677, loss 2.356
# step 678, loss 2.327
# step 679, loss 2.326
# step 680, loss 2.300
# step 681, loss 2.372
# step 682, loss 2.309
# step 683, loss 2.301
# step 684, loss 2.387
# step 685, loss 2.335
# step 686, loss 2.340
# step 687, loss 2.418
# step 688, loss 2.314
# step 689, loss 2.343
# step 690, loss 2.370
# step 691, loss 2.357
# step 692, loss 2.357
# step 693, loss 2.297
# step 694, loss 2.290
# step 695, loss 2.354
# step 696, loss 2.413
# step 697, loss 2.409
# step 698, loss 2.319
# step 699, loss 2.298
# step 700, loss 2.326
# step 701, loss 2.337
# step 702, loss 2.304
# step 703, loss 2.316
# step 704, loss 2.396
# step 705, loss 2.397
# step 706, loss 2.307
# step 707, loss 2.344
# step 708, loss 2.362
# step 709, loss 2.373
# step 710, loss 2.416
# step 711, loss 2.372
# step 712, loss 2.403
# step 713, loss 2.396
# step 714, loss 2.327
# step 715, loss 2.338
# step 716, loss 2.333
# step 717, loss 2.357
# step 718, loss 2.374
# step 719, loss 2.350
# step 720, loss 2.328
# step 721, loss 2.373
# step 722, loss 2.338
# step 723, loss 2.355
# step 724, loss 2.357
# step 725, loss 2.358
# step 726, loss 2.379
# step 727, loss 2.411
# step 728, loss 2.336
# step 729, loss 2.349
# step 730, loss 2.378
# step 731, loss 2.350
# step 732, loss 2.372
# step 733, loss 2.354
# step 734, loss 2.324
# step 735, loss 2.369
# step 736, loss 2.381
# step 737, loss 2.381
# step 738, loss 2.371
# step 739, loss 2.316
# step 740, loss 2.362
# step 741, loss 2.390
# step 742, loss 2.318
# step 743, loss 2.299
# step 744, loss 2.376
# step 745, loss 2.325
# step 746, loss 2.347
# step 747, loss 2.346
# step 748, loss 2.330
# step 749, loss 2.333
# step 750, loss 2.356
# step 751, loss 2.353
# step 752, loss 2.359
# step 753, loss 2.376
# step 754, loss 2.348
# step 755, loss 2.459
# step 756, loss 2.374
# step 757, loss 2.278
# step 758, loss 2.342
# step 759, loss 2.342
# step 760, loss 2.450
# step 761, loss 2.419
# step 762, loss 2.351
# step 763, loss 2.303
# step 764, loss 2.391
# step 765, loss 2.345
# step 766, loss 2.270
# step 767, loss 2.395
# step 768, loss 2.364
# step 769, loss 2.335
# step 770, loss 2.323
# step 771, loss 2.363
# step 772, loss 2.374
# step 773, loss 2.327
# step 774, loss 2.350
# step 775, loss 2.378
# step 776, loss 2.436
# step 777, loss 2.400
# step 778, loss 2.388
# step 779, loss 2.294
# step 780, loss 2.344
# step 781, loss 2.344
# step 782, loss 2.374
# step 783, loss 2.321
# step 784, loss 2.383
# step 785, loss 2.370
# step 786, loss 2.384
# step 787, loss 2.320
# step 788, loss 2.371
# step 789, loss 2.391
# step 790, loss 2.352
# step 791, loss 2.314
# step 792, loss 2.292
# step 793, loss 2.301
# step 794, loss 2.356
# step 795, loss 2.370
# step 796, loss 2.307
# step 797, loss 2.357
# step 798, loss 2.356
# step 799, loss 2.370
# step 800, loss 2.348
# step 801, loss 2.351
# step 802, loss 2.382
# step 803, loss 2.372
# step 804, loss 2.294
# step 805, loss 2.322
# step 806, loss 2.293
# step 807, loss 2.346
# step 808, loss 2.337
# step 809, loss 2.335
# step 810, loss 2.393
# step 811, loss 2.342
# step 812, loss 2.318
# step 813, loss 2.340
# step 814, loss 2.338
# step 815, loss 2.360
# step 816, loss 2.395
# step 817, loss 2.271
# step 818, loss 2.384
# step 819, loss 2.331
# step 820, loss 2.388
# step 821, loss 2.289
# step 822, loss 2.462
# step 823, loss 2.349
# step 824, loss 2.335
# step 825, loss 2.337
# step 826, loss 2.302
# step 827, loss 2.330
# step 828, loss 2.353
# step 829, loss 2.375
# step 830, loss 2.299
# step 831, loss 2.420
# step 832, loss 2.368
# step 833, loss 2.406
# step 834, loss 2.317
# step 835, loss 2.396
# step 836, loss 2.339
# step 837, loss 2.337
# step 838, loss 2.390
# step 839, loss 2.352
# step 840, loss 2.339
# step 841, loss 2.359
# step 842, loss 2.346
# step 843, loss 2.373
# step 844, loss 2.299
# step 845, loss 2.342
# step 846, loss 2.394
# step 847, loss 2.398
# step 848, loss 2.369
# step 849, loss 2.380
# step 850, loss 2.350
# step 851, loss 2.356
# step 852, loss 2.345
# step 853, loss 2.340
# step 854, loss 2.412
# step 855, loss 2.343
# step 856, loss 2.338
# step 857, loss 2.325
# step 858, loss 2.321
# step 859, loss 2.385
# step 860, loss 2.354
# step 861, loss 2.370
# step 862, loss 2.380
# step 863, loss 2.382
# step 864, loss 2.356
# step 865, loss 2.322
# step 866, loss 2.333
# step 867, loss 2.301
# step 868, loss 2.327
# step 869, loss 2.351
# step 870, loss 2.405
# step 871, loss 2.367
# step 872, loss 2.305
# step 873, loss 2.390
# step 874, loss 2.350
# step 875, loss 2.368
# step 876, loss 2.356
# step 877, loss 2.300
# step 878, loss 2.288
# step 879, loss 2.437
# step 880, loss 2.339
# step 881, loss 2.334
# step 882, loss 2.317
# step 883, loss 2.381
# step 884, loss 2.317
# step 885, loss 2.389
# step 886, loss 2.320
# step 887, loss 2.359
# step 888, loss 2.380
# step 889, loss 2.422
# step 890, loss 2.360
# step 891, loss 2.358
# step 892, loss 2.381
# step 893, loss 2.385
# step 894, loss 2.312
# step 895, loss 2.392
# step 896, loss 2.427
# step 897, loss 2.328
# step 898, loss 2.323
# step 899, loss 2.410
# step 900, loss 2.331
# step 901, loss 2.384
# step 902, loss 2.360
# step 903, loss 2.389
# step 904, loss 2.316
# step 905, loss 2.339
# step 906, loss 2.366
# step 907, loss 2.366
# step 908, loss 2.351
# step 909, loss 2.333
# step 910, loss 2.333
# step 911, loss 2.377
# step 912, loss 2.381
# step 913, loss 2.361
# step 914, loss 2.299
# step 915, loss 2.320
# step 916, loss 2.333
# step 917, loss 2.298
# step 918, loss 2.386
# step 919, loss 2.325
# step 920, loss 2.366
# step 921, loss 2.374
# step 922, loss 2.354
# step 923, loss 2.305
# step 924, loss 2.302
# step 925, loss 2.347
# step 926, loss 2.439
# step 927, loss 2.370
# step 928, loss 2.358
# step 929, loss 2.349
# step 930, loss 2.400
# step 931, loss 2.328
# step 932, loss 2.391
# step 933, loss 2.349
# step 934, loss 2.338
# step 935, loss 2.325
# step 936, loss 2.373
# step 937, loss 2.384
# step 938, loss 2.358
# step 939, loss 2.311
# step 940, loss 2.385
# step 941, loss 2.385
# step 942, loss 2.368
# step 943, loss 2.309
# step 944, loss 2.357
# step 945, loss 2.365
# step 946, loss 2.468
# step 947, loss 2.350
# step 948, loss 2.415
# step 949, loss 2.384
# step 950, loss 2.354
# step 951, loss 2.336
# step 952, loss 2.390
# step 953, loss 2.320
# step 954, loss 2.341
# step 955, loss 2.339
# step 956, loss 2.340
# step 957, loss 2.352
# step 958, loss 2.367
# step 959, loss 2.347
# step 960, loss 2.314
# step 961, loss 2.348
# step 962, loss 2.376
# step 963, loss 2.359
# step 964, loss 2.328
# step 965, loss 2.386
# step 966, loss 2.342
# step 967, loss 2.353
# step 968, loss 2.342
# step 969, loss 2.366
# step 970, loss 2.300
# step 971, loss 2.296
# step 972, loss 2.333
# step 973, loss 2.349
# step 974, loss 2.310
# step 975, loss 2.306
# step 976, loss 2.381
# step 977, loss 2.399
# step 978, loss 2.318
# step 979, loss 2.327
# step 980, loss 2.320
# step 981, loss 2.349
# step 982, loss 2.362
# step 983, loss 2.428
# step 984, loss 2.408
# step 985, loss 2.357
# step 986, loss 2.389
# step 987, loss 2.369
# step 988, loss 2.351
# step 989, loss 2.359
# step 990, loss 2.361
# step 991, loss 2.369
# step 992, loss 2.387
# step 993, loss 2.355
# step 994, loss 2.363
# step 995, loss 2.308
# step 996, loss 2.347
# step 997, loss 2.349
# step 998, loss 2.352
# step 999, loss 2.381
# step 1000, loss 2.320
# step 1001, loss 2.342
# step 1002, loss 2.330
# step 1003, loss 2.360
# step 1004, loss 2.370
# step 1005, loss 2.345
# step 1006, loss 2.310
# step 1007, loss 2.325
# step 1008, loss 2.304
# step 1009, loss 2.336
# step 1010, loss 2.385
# step 1011, loss 2.379
# step 1012, loss 2.330
# step 1013, loss 2.394
# step 1014, loss 2.367
# step 1015, loss 2.385
# step 1016, loss 2.350
# step 1017, loss 2.289
# step 1018, loss 2.327
# step 1019, loss 2.335
# step 1020, loss 2.307
# step 1021, loss 2.318
# step 1022, loss 2.334
# step 1023, loss 2.301
# step 1024, loss 2.334
# step 1025, loss 2.262
# step 1026, loss 2.356
# step 1027, loss 2.328
# step 1028, loss 2.250
# step 1029, loss 2.345
# step 1030, loss 2.279
# step 1031, loss 2.247
# step 1032, loss 2.332
# step 1033, loss 2.283
# step 1034, loss 2.357
# step 1035, loss 2.226
# step 1036, loss 2.234
# step 1037, loss 2.292
# step 1038, loss 2.182
# step 1039, loss 2.238
# step 1040, loss 2.230
# step 1041, loss 2.215
# step 1042, loss 2.173
# step 1043, loss 2.205
# step 1044, loss 2.169
# step 1045, loss 2.109
# step 1046, loss 2.231
# step 1047, loss 1.993
# step 1048, loss 2.094
# step 1049, loss 2.035
# step 1050, loss 2.002
# step 1051, loss 2.075
# step 1052, loss 1.962
# step 1053, loss 1.894
# step 1054, loss 1.993
# step 1055, loss 2.092
# step 1056, loss 1.973
# step 1057, loss 1.971
# step 1058, loss 2.124
# step 1059, loss 2.344
# step 1060, loss 2.241
# step 1061, loss 1.935
# step 1062, loss 1.998
# step 1063, loss 2.120
# step 1064, loss 2.082
# step 1065, loss 1.960
# step 1066, loss 1.939
# step 1067, loss 1.945
# step 1068, loss 1.974
# step 1069, loss 2.017
# step 1070, loss 2.068
# step 1071, loss 1.900
# step 1072, loss 1.988
# step 1073, loss 1.943
# step 1074, loss 1.967
# step 1075, loss 1.879
# step 1076, loss 1.810
# step 1077, loss 1.822
# step 1078, loss 1.972
# step 1079, loss 2.050
# step 1080, loss 1.749
# step 1081, loss 1.843
# step 1082, loss 1.861
# step 1083, loss 1.843
# step 1084, loss 1.740
# step 1085, loss 1.806
# step 1086, loss 1.820
# step 1087, loss 1.845
# step 1088, loss 1.880
# step 1089, loss 1.837
# step 1090, loss 1.743
# step 1091, loss 1.823
# step 1092, loss 1.767
# step 1093, loss 1.790
# step 1094, loss 1.740
# step 1095, loss 1.777
# step 1096, loss 1.782
# step 1097, loss 1.795
# step 1098, loss 1.648
# step 1099, loss 1.647
# step 1100, loss 1.848
# step 1101, loss 1.667
# step 1102, loss 1.570
# step 1103, loss 1.756
# step 1104, loss 1.758
# step 1105, loss 1.589
# step 1106, loss 1.566
# step 1107, loss 1.639
# step 1108, loss 1.744
# step 1109, loss 1.761
# step 1110, loss 1.620
# step 1111, loss 1.502
# step 1112, loss 1.610
# step 1113, loss 1.722
# step 1114, loss 1.655
# step 1115, loss 1.663
# step 1116, loss 1.442
# step 1117, loss 1.582
# step 1118, loss 1.568
# step 1119, loss 1.526
# step 1120, loss 1.322
# step 1121, loss 1.514
# step 1122, loss 1.443
# step 1123, loss 1.597
# step 1124, loss 1.382
# step 1125, loss 1.486
# step 1126, loss 1.664
# step 1127, loss 1.562
# step 1128, loss 1.740
# step 1129, loss 1.504
# step 1130, loss 1.501
# step 1131, loss 1.537
# step 1132, loss 1.601
# step 1133, loss 1.491
# step 1134, loss 1.511
# step 1135, loss 1.414
# step 1136, loss 1.456
# step 1137, loss 1.619
# step 1138, loss 1.440
# step 1139, loss 1.442
# step 1140, loss 1.509
# step 1141, loss 1.382
# step 1142, loss 1.631
# step 1143, loss 1.361
# step 1144, loss 1.540
# step 1145, loss 1.353
# step 1146, loss 1.440
# step 1147, loss 1.401
# step 1148, loss 1.456
# step 1149, loss 1.527
# step 1150, loss 1.265
# step 1151, loss 1.517
# step 1152, loss 1.410
# step 1153, loss 1.391
# step 1154, loss 1.402
# step 1155, loss 1.284
# step 1156, loss 1.300
# step 1157, loss 1.414
# step 1158, loss 1.286
# step 1159, loss 1.420
# step 1160, loss 1.374
# step 1161, loss 1.453
# step 1162, loss 1.223
# step 1163, loss 1.321
# step 1164, loss 1.367
# step 1165, loss 1.343
# step 1166, loss 1.304
# step 1167, loss 1.328
# step 1168, loss 1.223
# step 1169, loss 1.143
# step 1170, loss 1.228
# step 1171, loss 1.229
# step 1172, loss 1.197
# step 1173, loss 1.140
# step 1174, loss 1.208
# step 1175, loss 1.155
# step 1176, loss 1.256
# step 1177, loss 1.141
# step 1178, loss 1.235
# step 1179, loss 1.016
# step 1180, loss 1.255
# step 1181, loss 1.037
# step 1182, loss 1.082
# step 1183, loss 1.199
# step 1184, loss 1.142
# step 1185, loss 1.061
# step 1186, loss 1.125
# step 1187, loss 1.204
# step 1188, loss 1.140
# step 1189, loss 0.952
# step 1190, loss 1.117
# step 1191, loss 1.060
# step 1192, loss 1.041
# step 1193, loss 1.167
# step 1194, loss 1.178
# step 1195, loss 1.199
# step 1196, loss 0.909
# step 1197, loss 1.163
# step 1198, loss 1.045
# step 1199, loss 0.910
# step 1200, loss 0.955
# step 1201, loss 1.094
# step 1202, loss 0.998
# step 1203, loss 0.953
# step 1204, loss 0.822
# step 1205, loss 1.038
# step 1206, loss 0.992
# step 1207, loss 0.893
# step 1208, loss 0.993
# step 1209, loss 0.937
# step 1210, loss 1.029
# step 1211, loss 0.804
# step 1212, loss 1.017
# step 1213, loss 0.787
# step 1214, loss 0.602
# step 1215, loss 0.846
# step 1216, loss 0.647
# step 1217, loss 0.907
# step 1218, loss 0.847
# step 1219, loss 0.779
# step 1220, loss 0.863
# step 1221, loss 0.637
# step 1222, loss 0.712
# step 1223, loss 0.728
# step 1224, loss 0.861
# step 1225, loss 0.824
# step 1226, loss 0.818
# step 1227, loss 0.642
# step 1228, loss 0.752
# step 1229, loss 0.717
# step 1230, loss 0.830
# step 1231, loss 0.598
# step 1232, loss 0.818
# step 1233, loss 0.667
# step 1234, loss 0.800
# step 1235, loss 0.738
# step 1236, loss 0.516
# step 1237, loss 0.473
# step 1238, loss 0.607
# step 1239, loss 0.704
# step 1240, loss 0.667
# step 1241, loss 0.616
# step 1242, loss 0.727
# step 1243, loss 0.633
# step 1244, loss 0.510
# step 1245, loss 0.498
# step 1246, loss 0.643
# step 1247, loss 0.592
# step 1248, loss 0.691
# step 1249, loss 0.829
# step 1250, loss 0.607
# step 1251, loss 0.565
# step 1252, loss 0.604
# step 1253, loss 0.640
# step 1254, loss 0.527
# step 1255, loss 0.450
# step 1256, loss 0.448
# step 1257, loss 0.689
# step 1258, loss 0.594
# step 1259, loss 0.737
# step 1260, loss 0.964
# step 1261, loss 1.340
# step 1262, loss 1.303
# step 1263, loss 1.165
# step 1264, loss 1.395
# step 1265, loss 1.335
# step 1266, loss 1.748
# step 1267, loss 1.385
# step 1268, loss 1.265
# step 1269, loss 1.202
# step 1270, loss 1.246
# step 1271, loss 1.012
# step 1272, loss 1.102
# step 1273, loss 0.896
# step 1274, loss 0.941
# step 1275, loss 1.010
# step 1276, loss 1.070
# step 1277, loss 0.881
# step 1278, loss 1.024
# step 1279, loss 0.922
# step 1280, loss 0.909
# step 1281, loss 0.898
# step 1282, loss 0.835
# step 1283, loss 0.919
# step 1284, loss 0.893
# step 1285, loss 0.930
# step 1286, loss 0.955
# step 1287, loss 0.866
# step 1288, loss 0.867
# step 1289, loss 0.897
# step 1290, loss 0.849
# step 1291, loss 0.773
# step 1292, loss 0.734
# step 1293, loss 0.934
# step 1294, loss 0.600
# step 1295, loss 0.808
# step 1296, loss 0.737
# step 1297, loss 0.863
# step 1298, loss 0.566
# step 1299, loss 0.754
# step 1300, loss 0.873
# step 1301, loss 0.693
# step 1302, loss 0.601
# step 1303, loss 0.597
# step 1304, loss 0.697
# step 1305, loss 0.745
# step 1306, loss 0.817
# step 1307, loss 0.772
# step 1308, loss 0.898
# step 1309, loss 0.762
# step 1310, loss 0.745
# step 1311, loss 0.756
# step 1312, loss 0.641
# step 1313, loss 0.623
# step 1314, loss 0.863
# step 1315, loss 0.527
# step 1316, loss 0.645
# step 1317, loss 0.606
# step 1318, loss 0.639
# step 1319, loss 0.831
# step 1320, loss 0.617
# step 1321, loss 0.558
# step 1322, loss 0.704
# step 1323, loss 0.724
# step 1324, loss 0.672
# step 1325, loss 0.741
# step 1326, loss 0.626
# step 1327, loss 0.655
# step 1328, loss 0.544
# step 1329, loss 0.512
# step 1330, loss 0.563
# step 1331, loss 0.612
# step 1332, loss 0.497
# step 1333, loss 0.509
# step 1334, loss 0.700
# step 1335, loss 0.494
# step 1336, loss 0.438
# step 1337, loss 0.485
# step 1338, loss 0.601
# step 1339, loss 0.474
# step 1340, loss 0.739
# step 1341, loss 0.454
# step 1342, loss 0.396
# step 1343, loss 0.573
# step 1344, loss 0.398
# step 1345, loss 0.531
# step 1346, loss 0.522
# step 1347, loss 0.531
# step 1348, loss 0.500
# step 1349, loss 0.439
# step 1350, loss 0.479
# step 1351, loss 0.373
# step 1352, loss 0.461
# step 1353, loss 0.558
# step 1354, loss 0.335
# step 1355, loss 0.531
# step 1356, loss 0.590
# step 1357, loss 0.350
# step 1358, loss 0.329
# step 1359, loss 0.455
# step 1360, loss 0.563
# step 1361, loss 0.648
# step 1362, loss 0.519
# step 1363, loss 0.483
# step 1364, loss 0.483
# step 1365, loss 0.512
# step 1366, loss 0.497
# step 1367, loss 0.441
# step 1368, loss 0.476
# step 1369, loss 0.479
# step 1370, loss 0.528
# step 1371, loss 0.501
# step 1372, loss 0.704
# step 1373, loss 0.467
# step 1374, loss 0.385
# step 1375, loss 0.515
# step 1376, loss 0.398
# step 1377, loss 0.415
# step 1378, loss 0.498
# step 1379, loss 0.600
# step 1380, loss 0.385
# step 1381, loss 0.461
# step 1382, loss 0.581
# step 1383, loss 0.506
# step 1384, loss 0.512
# step 1385, loss 0.522
# step 1386, loss 0.522
# step 1387, loss 0.657
# step 1388, loss 0.602
# step 1389, loss 0.606
# step 1390, loss 0.379
# step 1391, loss 0.524
# step 1392, loss 0.443
# step 1393, loss 0.442
# step 1394, loss 0.404
# step 1395, loss 0.286
# step 1396, loss 0.373
# step 1397, loss 0.572
# step 1398, loss 0.521
# step 1399, loss 0.363
# step 1400, loss 0.535
# step 1401, loss 0.460
# step 1402, loss 0.404
# step 1403, loss 0.306
# step 1404, loss 0.402
# step 1405, loss 0.380
# step 1406, loss 0.327
# step 1407, loss 0.469
# step 1408, loss 0.431
# step 1409, loss 0.270
# step 1410, loss 0.442
# step 1411, loss 0.326
# step 1412, loss 0.452
# step 1413, loss 0.400
# step 1414, loss 0.408
# step 1415, loss 0.545
# step 1416, loss 0.435
# step 1417, loss 0.440
# step 1418, loss 0.238
# step 1419, loss 0.348
# step 1420, loss 0.541
# step 1421, loss 0.306
# step 1422, loss 0.199
# step 1423, loss 0.252
# step 1424, loss 0.352
# step 1425, loss 0.380
# step 1426, loss 0.298
# step 1427, loss 0.302
# step 1428, loss 0.448
# step 1429, loss 0.309
# step 1430, loss 0.296
# step 1431, loss 0.306
# step 1432, loss 0.281
# step 1433, loss 0.389
# step 1434, loss 0.459
# step 1435, loss 0.256
# step 1436, loss 0.258
# step 1437, loss 0.266
# step 1438, loss 0.227
# step 1439, loss 0.267
# step 1440, loss 0.527
# step 1441, loss 0.444
# step 1442, loss 0.386
# step 1443, loss 0.354
# step 1444, loss 0.383
# step 1445, loss 0.340
# step 1446, loss 0.381
# step 1447, loss 0.343
# step 1448, loss 0.222
# step 1449, loss 0.157
# step 1450, loss 0.354
# step 1451, loss 0.333
# step 1452, loss 0.422
# step 1453, loss 0.273
# step 1454, loss 0.306
# step 1455, loss 0.352
# step 1456, loss 0.351
# step 1457, loss 0.435
# step 1458, loss 0.320
# step 1459, loss 0.317
# step 1460, loss 0.302
# step 1461, loss 0.457
# step 1462, loss 0.545
# step 1463, loss 0.474
# step 1464, loss 0.461
# step 1465, loss 0.299
# step 1466, loss 0.277
# step 1467, loss 0.363
# step 1468, loss 0.301
# step 1469, loss 0.304
# step 1470, loss 0.416
# step 1471, loss 0.345
# step 1472, loss 0.419
# step 1473, loss 0.158
# step 1474, loss 0.409
# step 1475, loss 0.268
# step 1476, loss 0.386
# step 1477, loss 0.648
# step 1478, loss 0.343
# step 1479, loss 0.319
# step 1480, loss 0.451
# step 1481, loss 0.446
# step 1482, loss 0.369
# step 1483, loss 0.297
# step 1484, loss 0.347
# step 1485, loss 0.442
# step 1486, loss 0.350
# step 1487, loss 0.439
# step 1488, loss 0.294
# step 1489, loss 0.293
# step 1490, loss 0.279
# step 1491, loss 0.324
# step 1492, loss 0.413
# step 1493, loss 0.167
# step 1494, loss 0.386
# step 1495, loss 0.392
# step 1496, loss 0.163
# step 1497, loss 0.312
# step 1498, loss 0.372
# step 1499, loss 0.487
# step 1500, loss 0.266
# step 1501, loss 0.270
# step 1502, loss 0.334
# step 1503, loss 0.270
# step 1504, loss 0.349
# step 1505, loss 0.386
# step 1506, loss 0.285
# step 1507, loss 0.486
# step 1508, loss 0.319
# step 1509, loss 0.396
# step 1510, loss 0.360
# step 1511, loss 0.312
# step 1512, loss 0.266
# step 1513, loss 0.155
# step 1514, loss 0.286
# step 1515, loss 0.153
# step 1516, loss 0.377
# step 1517, loss 0.262
# step 1518, loss 0.229
# step 1519, loss 0.390
# step 1520, loss 0.227
# step 1521, loss 0.140
# step 1522, loss 0.231
# step 1523, loss 0.337
# step 1524, loss 0.286
# step 1525, loss 0.262
# step 1526, loss 0.260
# step 1527, loss 0.126
# step 1528, loss 0.264
# step 1529, loss 0.432
# step 1530, loss 0.441
# step 1531, loss 0.363
# step 1532, loss 0.261
# step 1533, loss 0.339
# step 1534, loss 0.145
# step 1535, loss 0.215
# step 1536, loss 0.232
# step 1537, loss 0.283
# step 1538, loss 0.126
# step 1539, loss 0.441
# step 1540, loss 0.305
# step 1541, loss 0.245
# step 1542, loss 0.235
# step 1543, loss 0.145
# step 1544, loss 0.254
# step 1545, loss 0.188
# step 1546, loss 0.370
# step 1547, loss 0.291
# step 1548, loss 0.327
# step 1549, loss 0.310
# step 1550, loss 0.175
# step 1551, loss 0.208
# step 1552, loss 0.208
# step 1553, loss 0.211
# step 1554, loss 0.410
# step 1555, loss 0.241
# step 1556, loss 0.189
# step 1557, loss 0.456
# step 1558, loss 0.272
# step 1559, loss 0.328
# step 1560, loss 0.283
# step 1561, loss 0.217
# step 1562, loss 0.273
# step 1563, loss 0.172
# step 1564, loss 0.261
# step 1565, loss 0.235
# step 1566, loss 0.273
# step 1567, loss 0.342
# step 1568, loss 0.193
# step 1569, loss 0.283
# step 1570, loss 0.274
# step 1571, loss 0.232
# step 1572, loss 0.394
# step 1573, loss 0.326
# step 1574, loss 0.300
# step 1575, loss 0.193
# step 1576, loss 0.201
# step 1577, loss 0.161
# step 1578, loss 0.308
# step 1579, loss 0.344
# step 1580, loss 0.191
# step 1581, loss 0.224
# step 1582, loss 0.371
# step 1583, loss 0.228
# step 1584, loss 0.223
# step 1585, loss 0.365
# step 1586, loss 0.305
# step 1587, loss 0.347
# step 1588, loss 0.243
# step 1589, loss 0.396
# step 1590, loss 0.218
# step 1591, loss 0.333
# step 1592, loss 0.274
# step 1593, loss 0.286
# step 1594, loss 0.196
# step 1595, loss 0.416
# step 1596, loss 0.260
# step 1597, loss 0.290
# step 1598, loss 0.290
# step 1599, loss 0.243
# step 1600, loss 0.262
# step 1601, loss 0.137
# step 1602, loss 0.367
# step 1603, loss 0.230
# step 1604, loss 0.280
# step 1605, loss 0.364
# step 1606, loss 0.200
# step 1607, loss 0.290
# step 1608, loss 0.336
# step 1609, loss 0.236
# step 1610, loss 0.148
# step 1611, loss 0.259
# step 1612, loss 0.201
# step 1613, loss 0.234
# step 1614, loss 0.275
# step 1615, loss 0.142
# step 1616, loss 0.186
# step 1617, loss 0.266
# step 1618, loss 0.274
# step 1619, loss 0.224
# step 1620, loss 0.266
# step 1621, loss 0.224
# step 1622, loss 0.110
# step 1623, loss 0.136
# step 1624, loss 0.242
# step 1625, loss 0.104
# step 1626, loss 0.219
# step 1627, loss 0.281
# step 1628, loss 0.243
# step 1629, loss 0.330
# step 1630, loss 0.207
# step 1631, loss 0.183
# step 1632, loss 0.293
# step 1633, loss 0.197
# step 1634, loss 0.266
# step 1635, loss 0.275
# step 1636, loss 0.197
# step 1637, loss 0.292
# step 1638, loss 0.159
# step 1639, loss 0.229
# step 1640, loss 0.320
# step 1641, loss 0.102
# step 1642, loss 0.105
# step 1643, loss 0.148
# step 1644, loss 0.163
# step 1645, loss 0.248
# step 1646, loss 0.297
# step 1647, loss 0.210
# step 1648, loss 0.230
# step 1649, loss 0.180
# step 1650, loss 0.181
# step 1651, loss 0.163
# step 1652, loss 0.116
# step 1653, loss 0.263
# step 1654, loss 0.163
# step 1655, loss 0.285
# step 1656, loss 0.242
# step 1657, loss 0.043
# step 1658, loss 0.215
# step 1659, loss 0.283
# step 1660, loss 0.181
# step 1661, loss 0.304
# step 1662, loss 0.242
# step 1663, loss 0.235
# step 1664, loss 0.233
# step 1665, loss 0.257
# step 1666, loss 0.266
# step 1667, loss 0.200
# step 1668, loss 0.242
# step 1669, loss 0.355
# step 1670, loss 0.169
# step 1671, loss 0.435
# step 1672, loss 0.181
# step 1673, loss 0.383
# step 1674, loss 0.359
# step 1675, loss 0.200
# step 1676, loss 0.200
# step 1677, loss 0.151
# step 1678, loss 0.282
# step 1679, loss 0.224
# step 1680, loss 0.130
# step 1681, loss 0.120
# step 1682, loss 0.252
# step 1683, loss 0.271
# step 1684, loss 0.164
# step 1685, loss 0.398
# step 1686, loss 0.124
# step 1687, loss 0.081
# step 1688, loss 0.168
# step 1689, loss 0.321
# step 1690, loss 0.195
# step 1691, loss 0.261
# step 1692, loss 0.307
# step 1693, loss 0.206
# step 1694, loss 0.273
# step 1695, loss 0.375
# step 1696, loss 0.213
# step 1697, loss 0.148
# step 1698, loss 0.266
# step 1699, loss 0.204
# step 1700, loss 0.105
# step 1701, loss 0.175
# step 1702, loss 0.324
# step 1703, loss 0.196
# step 1704, loss 0.134
# step 1705, loss 0.216
# step 1706, loss 0.277
# step 1707, loss 0.365
# step 1708, loss 0.181
# step 1709, loss 0.220
# step 1710, loss 0.186
# step 1711, loss 0.261
# step 1712, loss 0.116
# step 1713, loss 0.223
# step 1714, loss 0.282
# step 1715, loss 0.227
# step 1716, loss 0.251
# step 1717, loss 0.221
# step 1718, loss 0.155
# step 1719, loss 0.269
# step 1720, loss 0.170
# step 1721, loss 0.218
# step 1722, loss 0.101
# step 1723, loss 0.230
# step 1724, loss 0.229
# step 1725, loss 0.171
# step 1726, loss 0.076
# step 1727, loss 0.193
# step 1728, loss 0.147
# step 1729, loss 0.224
# step 1730, loss 0.171
# step 1731, loss 0.170
# step 1732, loss 0.137
# step 1733, loss 0.222
# step 1734, loss 0.258
# step 1735, loss 0.095
# step 1736, loss 0.248
# step 1737, loss 0.201
# step 1738, loss 0.223
# step 1739, loss 0.159
# step 1740, loss 0.272
# step 1741, loss 0.245
# step 1742, loss 0.132
# step 1743, loss 0.161
# step 1744, loss 0.169
# step 1745, loss 0.123
# step 1746, loss 0.222
# step 1747, loss 0.169
# step 1748, loss 0.155
# step 1749, loss 0.244
# step 1750, loss 0.196
# step 1751, loss 0.232
# step 1752, loss 0.367
# step 1753, loss 0.257
# step 1754, loss 0.458
# step 1755, loss 0.314
# step 1756, loss 0.609
# step 1757, loss 0.407
# step 1758, loss 0.237
# step 1759, loss 0.260
# step 1760, loss 0.236
# step 1761, loss 0.329
# step 1762, loss 0.348
# step 1763, loss 0.357
# step 1764, loss 0.418
# step 1765, loss 0.152
# step 1766, loss 0.258
# step 1767, loss 0.339
# step 1768, loss 0.276
# step 1769, loss 0.382
# step 1770, loss 0.369
# step 1771, loss 0.427
# step 1772, loss 0.340
# step 1773, loss 0.297
# step 1774, loss 0.354
# step 1775, loss 0.297
# step 1776, loss 0.291
# step 1777, loss 0.322
# step 1778, loss 0.324
# step 1779, loss 0.116
# step 1780, loss 0.292
# step 1781, loss 0.269
# step 1782, loss 0.380
# step 1783, loss 0.168
# step 1784, loss 0.272
# step 1785, loss 0.264
# step 1786, loss 0.092
# step 1787, loss 0.108
# step 1788, loss 0.237
# step 1789, loss 0.206
# step 1790, loss 0.202
# step 1791, loss 0.281
# step 1792, loss 0.161
# step 1793, loss 0.272
# step 1794, loss 0.203
# step 1795, loss 0.218
# step 1796, loss 0.228
# step 1797, loss 0.280
# step 1798, loss 0.179
# step 1799, loss 0.239
# step 1800, loss 0.180
# step 1801, loss 0.346
# step 1802, loss 0.156
# step 1803, loss 0.281
# step 1804, loss 0.168
# step 1805, loss 0.157
# step 1806, loss 0.185
# step 1807, loss 0.130
# step 1808, loss 0.183
# step 1809, loss 0.151
# step 1810, loss 0.258
# step 1811, loss 0.144
# step 1812, loss 0.168
# step 1813, loss 0.106
# step 1814, loss 0.137
# step 1815, loss 0.181
# step 1816, loss 0.235
# step 1817, loss 0.134
# step 1818, loss 0.308
# step 1819, loss 0.152
# step 1820, loss 0.173
# step 1821, loss 0.285
# step 1822, loss 0.154
# step 1823, loss 0.206
# step 1824, loss 0.186
# step 1825, loss 0.179
# step 1826, loss 0.239
# step 1827, loss 0.151
# step 1828, loss 0.236
# step 1829, loss 0.386
# step 1830, loss 0.296
# step 1831, loss 0.120
# step 1832, loss 0.161
# step 1833, loss 0.226
# step 1834, loss 0.142
# step 1835, loss 0.129
# step 1836, loss 0.230
# step 1837, loss 0.115
# step 1838, loss 0.288
# step 1839, loss 0.329
# step 1840, loss 0.281
# step 1841, loss 0.117
# step 1842, loss 0.130
# step 1843, loss 0.065
# step 1844, loss 0.264
# step 1845, loss 0.232
# step 1846, loss 0.126
# step 1847, loss 0.147
# step 1848, loss 0.156
# step 1849, loss 0.150
# step 1850, loss 0.150
# step 1851, loss 0.090
# step 1852, loss 0.210
# step 1853, loss 0.081
# step 1854, loss 0.253
# step 1855, loss 0.289
# step 1856, loss 0.063
# step 1857, loss 0.192
# step 1858, loss 0.111
# step 1859, loss 0.291
# step 1860, loss 0.123
# step 1861, loss 0.122
# step 1862, loss 0.131
# step 1863, loss 0.227
# step 1864, loss 0.244
# step 1865, loss 0.172
# step 1866, loss 0.243
# step 1867, loss 0.105
# step 1868, loss 0.206
# step 1869, loss 0.222
# step 1870, loss 0.162
# step 1871, loss 0.086
# step 1872, loss 0.178
# step 1873, loss 0.171
# step 1874, loss 0.213
# step 1875, loss 0.098
# step 1876, loss 0.106
# step 1877, loss 0.317
# step 1878, loss 0.230
# step 1879, loss 0.128
# step 1880, loss 0.198
# step 1881, loss 0.158
# step 1882, loss 0.255
# step 1883, loss 0.181
# step 1884, loss 0.241
# step 1885, loss 0.113
# step 1886, loss 0.130
# step 1887, loss 0.153
# step 1888, loss 0.346
# step 1889, loss 0.096
# step 1890, loss 0.060
# step 1891, loss 0.160
# step 1892, loss 0.126
# step 1893, loss 0.206
# step 1894, loss 0.173
# step 1895, loss 0.101
# step 1896, loss 0.178
# step 1897, loss 0.177
# step 1898, loss 0.230
# step 1899, loss 0.129
# step 1900, loss 0.120
# step 1901, loss 0.198
# step 1902, loss 0.154
# step 1903, loss 0.172
# step 1904, loss 0.107
# step 1905, loss 0.139
# step 1906, loss 0.099
# step 1907, loss 0.184
# step 1908, loss 0.122
# step 1909, loss 0.072
# step 1910, loss 0.116
# step 1911, loss 0.065
# step 1912, loss 0.166
# step 1913, loss 0.049
# step 1914, loss 0.116
# step 1915, loss 0.175
# step 1916, loss 0.222
# step 1917, loss 0.139
# step 1918, loss 0.187
# step 1919, loss 0.122
# step 1920, loss 0.097
# step 1921, loss 0.161
# step 1922, loss 0.290
# step 1923, loss 0.169
# step 1924, loss 0.205
# step 1925, loss 0.127
# step 1926, loss 0.111
# step 1927, loss 0.156
# step 1928, loss 0.124
# step 1929, loss 0.328
# step 1930, loss 0.039
# step 1931, loss 0.226
# step 1932, loss 0.205
# step 1933, loss 0.123
# step 1934, loss 0.145
# step 1935, loss 0.191
# step 1936, loss 0.131
# step 1937, loss 0.133
# step 1938, loss 0.261
# step 1939, loss 0.160
# step 1940, loss 0.218
# step 1941, loss 0.164
# step 1942, loss 0.149
# step 1943, loss 0.116
# step 1944, loss 0.226
# step 1945, loss 0.140
# step 1946, loss 0.209
# step 1947, loss 0.126
# step 1948, loss 0.140
# step 1949, loss 0.161
# step 1950, loss 0.099
# step 1951, loss 0.079
# step 1952, loss 0.237
# step 1953, loss 0.140
# step 1954, loss 0.099
# step 1955, loss 0.186
# step 1956, loss 0.205
# step 1957, loss 0.096
# step 1958, loss 0.103
# step 1959, loss 0.173
# step 1960, loss 0.130
# step 1961, loss 0.153
# step 1962, loss 0.033
# step 1963, loss 0.142
# step 1964, loss 0.281
# step 1965, loss 0.089
# step 1966, loss 0.273
# step 1967, loss 0.107
# step 1968, loss 0.061
# step 1969, loss 0.108
# step 1970, loss 0.106
# step 1971, loss 0.124
# step 1972, loss 0.059
# step 1973, loss 0.115
# step 1974, loss 0.108
# step 1975, loss 0.176
# step 1976, loss 0.127
# step 1977, loss 0.135
# step 1978, loss 0.030
# step 1979, loss 0.058
# step 1980, loss 0.052
# step 1981, loss 0.193
# step 1982, loss 0.043
# step 1983, loss 0.128
# step 1984, loss 0.088
# step 1985, loss 0.168
# step 1986, loss 0.155
# step 1987, loss 0.088
# step 1988, loss 0.112
# step 1989, loss 0.121
# step 1990, loss 0.187
# step 1991, loss 0.073
# step 1992, loss 0.023
# step 1993, loss 0.106
# step 1994, loss 0.171
# step 1995, loss 0.212
# step 1996, loss 0.037
# step 1997, loss 0.256
# step 1998, loss 0.174
# step 1999, loss 0.043
# step 2000, loss 0.112
# step 2001, loss 0.035
# step 2002, loss 0.107
# step 2003, loss 0.122
# step 2004, loss 0.210
# step 2005, loss 0.052
# step 2006, loss 0.122
# step 2007, loss 0.098
# step 2008, loss 0.087
# step 2009, loss 0.176
# step 2010, loss 0.058
# step 2011, loss 0.107
# step 2012, loss 0.222
# step 2013, loss 0.107
# step 2014, loss 0.311
# step 2015, loss 0.168
# step 2016, loss 0.094
# step 2017, loss 0.131
# step 2018, loss 0.156
# step 2019, loss 0.122
# step 2020, loss 0.081
# step 2021, loss 0.140
# step 2022, loss 0.159
# step 2023, loss 0.119
# step 2024, loss 0.192
# step 2025, loss 0.092
# step 2026, loss 0.162
# step 2027, loss 0.336
# step 2028, loss 0.098
# step 2029, loss 0.320
# step 2030, loss 0.070
# step 2031, loss 0.117
# step 2032, loss 0.111
# step 2033, loss 0.072
# step 2034, loss 0.102
# step 2035, loss 0.075
# step 2036, loss 0.098
# step 2037, loss 0.123
# step 2038, loss 0.125
# step 2039, loss 0.086
# step 2040, loss 0.071
# step 2041, loss 0.155
# step 2042, loss 0.137
# step 2043, loss 0.062
# step 2044, loss 0.114
# step 2045, loss 0.248
# step 2046, loss 0.228
# step 2047, loss 0.108
# step 2048, loss 0.055
# step 2049, loss 0.141
# step 2050, loss 0.135
# step 2051, loss 0.090
# step 2052, loss 0.199
# step 2053, loss 0.145
# step 2054, loss 0.326
# step 2055, loss 0.200
# step 2056, loss 0.157
# step 2057, loss 0.166
# step 2058, loss 0.087
# step 2059, loss 0.146
# step 2060, loss 0.154
# step 2061, loss 0.089
# step 2062, loss 0.215
# step 2063, loss 0.208
# step 2064, loss 0.181
# step 2065, loss 0.107
# step 2066, loss 0.090
# step 2067, loss 0.184
# step 2068, loss 0.082
# step 2069, loss 0.169
# step 2070, loss 0.089
# step 2071, loss 0.064
# step 2072, loss 0.071
# step 2073, loss 0.255
# step 2074, loss 0.091
# step 2075, loss 0.118
# step 2076, loss 0.136
# step 2077, loss 0.152
# step 2078, loss 0.074
# step 2079, loss 0.105
# step 2080, loss 0.097
# step 2081, loss 0.070
# step 2082, loss 0.100
# step 2083, loss 0.073
# step 2084, loss 0.246
# step 2085, loss 0.061
# step 2086, loss 0.039
# step 2087, loss 0.136
# step 2088, loss 0.085
# step 2089, loss 0.113
# step 2090, loss 0.232
# step 2091, loss 0.161
# step 2092, loss 0.099
# step 2093, loss 0.077
# step 2094, loss 0.182
# step 2095, loss 0.152
# step 2096, loss 0.090
# step 2097, loss 0.135
# step 2098, loss 0.194
# step 2099, loss 0.089
# step 2100, loss 0.273
# step 2101, loss 0.165
# step 2102, loss 0.096
# step 2103, loss 0.171
# step 2104, loss 0.035
# step 2105, loss 0.110
# step 2106, loss 0.094
# step 2107, loss 0.145
# step 2108, loss 0.191
# step 2109, loss 0.097
# step 2110, loss 0.059
# step 2111, loss 0.071
# step 2112, loss 0.150
# step 2113, loss 0.102
# step 2114, loss 0.184
# step 2115, loss 0.030
# step 2116, loss 0.106
# step 2117, loss 0.045
# step 2118, loss 0.104
# step 2119, loss 0.130
# step 2120, loss 0.158
# step 2121, loss 0.067
# step 2122, loss 0.090
# step 2123, loss 0.128
# step 2124, loss 0.159
# step 2125, loss 0.059
# step 2126, loss 0.106
# step 2127, loss 0.105
# step 2128, loss 0.160
# step 2129, loss 0.021
# step 2130, loss 0.128
# step 2131, loss 0.081
# step 2132, loss 0.244
# step 2133, loss 0.185
# step 2134, loss 0.081
# step 2135, loss 0.089
# step 2136, loss 0.031
# step 2137, loss 0.162
# step 2138, loss 0.072
# step 2139, loss 0.144
# step 2140, loss 0.115
# step 2141, loss 0.175
# step 2142, loss 0.268
# step 2143, loss 0.068
# step 2144, loss 0.075
# step 2145, loss 0.179
# step 2146, loss 0.217
# step 2147, loss 0.162
# step 2148, loss 0.130
# step 2149, loss 0.149
# step 2150, loss 0.154
# step 2151, loss 0.046
# step 2152, loss 0.200
# step 2153, loss 0.065
# step 2154, loss 0.061
# step 2155, loss 0.182
# step 2156, loss 0.033
# step 2157, loss 0.100
# step 2158, loss 0.089
# step 2159, loss 0.182
# step 2160, loss 0.199
# step 2161, loss 0.058
# step 2162, loss 0.083
# step 2163, loss 0.144
# step 2164, loss 0.123
# step 2165, loss 0.144
# step 2166, loss 0.048
# step 2167, loss 0.207
# step 2168, loss 0.240
# step 2169, loss 0.174
# step 2170, loss 0.196
# step 2171, loss 0.061
# step 2172, loss 0.118
# step 2173, loss 0.160
# step 2174, loss 0.173
# step 2175, loss 0.039
# step 2176, loss 0.103
# step 2177, loss 0.124
# step 2178, loss 0.133
# step 2179, loss 0.064
# step 2180, loss 0.074
# step 2181, loss 0.147
# step 2182, loss 0.172
# step 2183, loss 0.207
# step 2184, loss 0.068
# step 2185, loss 0.130
# step 2186, loss 0.146
# step 2187, loss 0.164
# step 2188, loss 0.110
# step 2189, loss 0.059
# step 2190, loss 0.074
# step 2191, loss 0.185
# step 2192, loss 0.123
# step 2193, loss 0.047
# step 2194, loss 0.178
# step 2195, loss 0.035
# step 2196, loss 0.127
# step 2197, loss 0.067
# step 2198, loss 0.199
# step 2199, loss 0.056
# step 2200, loss 0.111
# step 2201, loss 0.051
# step 2202, loss 0.170
# step 2203, loss 0.056
# step 2204, loss 0.093
# step 2205, loss 0.051
# step 2206, loss 0.024
# step 2207, loss 0.126
# step 2208, loss 0.096
# step 2209, loss 0.061
# step 2210, loss 0.021
# step 2211, loss 0.072
# step 2212, loss 0.191
# step 2213, loss 0.156
# step 2214, loss 0.143
# step 2215, loss 0.068
# step 2216, loss 0.248
# step 2217, loss 0.036
# step 2218, loss 0.172
# step 2219, loss 0.051
# step 2220, loss 0.156
# step 2221, loss 0.131
# step 2222, loss 0.038
# step 2223, loss 0.100
# step 2224, loss 0.178
# step 2225, loss 0.114
# step 2226, loss 0.059
# step 2227, loss 0.288
# step 2228, loss 0.042
# step 2229, loss 0.103
# step 2230, loss 0.118
# step 2231, loss 0.083
# ...
# step 3999, loss 0.003
# step 4000, loss 0.011
# step 4001, loss 0.073
# step 4002, loss 0.045
# step 4003, loss 0.028
# step 4004, loss 0.007
# step 4005, loss 0.007
# step 4006, loss 0.020
# step 4007, loss 0.014
# step 4008, loss 0.065
# step 4009, loss 0.035
# step 4010, loss 0.044
# step 4011, loss 0.006
# step 4012, loss 0.007
# step 4013, loss 0.023
# step 4014, loss 0.058
# step 4015, loss 0.002
# step 4016, loss 0.014
# step 4017, loss 0.043
# step 4018, loss 0.011
# step 4019, loss 0.022
# step 4020, loss 0.021
# step 4021, loss 0.063
# step 4022, loss 0.024
# step 4023, loss 0.024
# step 4024, loss 0.051
# step 4025, loss 0.015
# step 4026, loss 0.022
# step 4027, loss 0.037
# step 4028, loss 0.016
# step 4029, loss 0.003
# step 4030, loss 0.009
# step 4031, loss 0.038
# step 4032, loss 0.060
# step 4033, loss 0.077
# step 4034, loss 0.006
# step 4035, loss 0.086
# step 4036, loss 0.004
# step 4037, loss 0.011
# step 4038, loss 0.058
# step 4039, loss 0.007
# step 4040, loss 0.016
# step 4041, loss 0.050
# step 4042, loss 0.004
# step 4043, loss 0.005
# step 4044, loss 0.007
# step 4045, loss 0.037
# step 4046, loss 0.045
# step 4047, loss 0.015
# step 4048, loss 0.036
# step 4049, loss 0.002
# step 4050, loss 0.002
# step 4051, loss 0.026
# step 4052, loss 0.006
# step 4053, loss 0.025
# step 4054, loss 0.006
# step 4055, loss 0.010
# step 4056, loss 0.017
# step 4057, loss 0.017
# step 4058, loss 0.046
# step 4059, loss 0.141
# step 4060, loss 0.011
# step 4061, loss 0.004
# step 4062, loss 0.049
# step 4063, loss 0.058
# step 4064, loss 0.021
# step 4065, loss 0.028
# step 4066, loss 0.047
# step 4067, loss 0.004
# step 4068, loss 0.022
# step 4069, loss 0.042
# step 4070, loss 0.029
# step 4071, loss 0.012
# step 4072, loss 0.006
# step 4073, loss 0.010
# step 4074, loss 0.004
# step 4075, loss 0.002
# step 4076, loss 0.012
# step 4077, loss 0.014
# step 4078, loss 0.036
# step 4079, loss 0.025
# step 4080, loss 0.002
# step 4081, loss 0.005
# step 4082, loss 0.003
# step 4083, loss 0.020
# step 4084, loss 0.003
# step 4085, loss 0.046
# step 4086, loss 0.007
# step 4087, loss 0.002
# step 4088, loss 0.061
# step 4089, loss 0.002
# step 4090, loss 0.003
# step 4091, loss 0.013
# step 4092, loss 0.006
# step 4093, loss 0.003
# step 4094, loss 0.027
# step 4095, loss 0.063
# step 4096, loss 0.022
# step 4097, loss 0.010
# step 4098, loss 0.006
# step 4099, loss 0.003
# step 4100, loss 0.055
# step 4101, loss 0.112
# step 4102, loss 0.013
# step 4103, loss 0.003
# step 4104, loss 0.025
# step 4105, loss 0.004
# step 4106, loss 0.003
# step 4107, loss 0.036
# step 4108, loss 0.010
# step 4109, loss 0.024
# step 4110, loss 0.018
# step 4111, loss 0.010
# step 4112, loss 0.013
# step 4113, loss 0.007
# step 4114, loss 0.008
# step 4115, loss 0.015
# step 4116, loss 0.062
# step 4117, loss 0.005
# step 4118, loss 0.081
# step 4119, loss 0.004
# step 4120, loss 0.081
# step 4121, loss 0.042
# step 4122, loss 0.039
# step 4123, loss 0.032
# step 4124, loss 0.019
# step 4125, loss 0.008
# step 4126, loss 0.052
# step 4127, loss 0.014
# step 4128, loss 0.032
# step 4129, loss 0.007
# step 4130, loss 0.004
# step 4131, loss 0.017
# step 4132, loss 0.032
# step 4133, loss 0.001
# step 4134, loss 0.044
# step 4135, loss 0.015
# step 4136, loss 0.048
# step 4137, loss 0.003
# step 4138, loss 0.003
# step 4139, loss 0.011
# step 4140, loss 0.041
# step 4141, loss 0.007
# step 4142, loss 0.004
# step 4143, loss 0.004
# step 4144, loss 0.064
# step 4145, loss 0.036
# step 4146, loss 0.053
# step 4147, loss 0.011
# step 4148, loss 0.012
# step 4149, loss 0.013
# step 4150, loss 0.003
# step 4151, loss 0.006
# step 4152, loss 0.019
# step 4153, loss 0.066
# step 4154, loss 0.029
# step 4155, loss 0.060
# step 4156, loss 0.008
# step 4157, loss 0.062
# step 4158, loss 0.005
# step 4159, loss 0.025
# step 4160, loss 0.011
# step 4161, loss 0.027
# step 4162, loss 0.002
# step 4163, loss 0.021
# step 4164, loss 0.047
# step 4165, loss 0.052
# step 4166, loss 0.001
# step 4167, loss 0.001
# step 4168, loss 0.051
# step 4169, loss 0.017
# step 4170, loss 0.012
# step 4171, loss 0.050
# step 4172, loss 0.012
# step 4173, loss 0.058
# step 4174, loss 0.064
# step 4175, loss 0.055
# step 4176, loss 0.022
# step 4177, loss 0.010
# step 4178, loss 0.045
# step 4179, loss 0.006
# step 4180, loss 0.018
# step 4181, loss 0.120
# step 4182, loss 0.004
# step 4183, loss 0.060
# step 4184, loss 0.036
# step 4185, loss 0.060
# step 4186, loss 0.003
# step 4187, loss 0.010
# step 4188, loss 0.014
# step 4189, loss 0.007
# step 4190, loss 0.013
# step 4191, loss 0.010
# step 4192, loss 0.005
# step 4193, loss 0.017
# step 4194, loss 0.006
# step 4195, loss 0.006
# step 4196, loss 0.090
# step 4197, loss 0.002
# step 4198, loss 0.005
# step 4199, loss 0.005
# step 4200, loss 0.005
# step 4201, loss 0.092
# step 4202, loss 0.015
# step 4203, loss 0.008
# step 4204, loss 0.018
# step 4205, loss 0.009
# step 4206, loss 0.052
# step 4207, loss 0.011
# step 4208, loss 0.008
# step 4209, loss 0.002
# step 4210, loss 0.019
# step 4211, loss 0.019
# step 4212, loss 0.057
# step 4213, loss 0.043
# step 4214, loss 0.045
# step 4215, loss 0.057
# step 4216, loss 0.017
# step 4217, loss 0.013
# step 4218, loss 0.001
# step 4219, loss 0.057
# step 4220, loss 0.001
# step 4221, loss 0.030
# step 4222, loss 0.036
# step 4223, loss 0.045
# step 4224, loss 0.008
# step 4225, loss 0.004
# step 4226, loss 0.049
# step 4227, loss 0.031
# step 4228, loss 0.014
# step 4229, loss 0.031
# step 4230, loss 0.017
# step 4231, loss 0.018
# step 4232, loss 0.001
# step 4233, loss 0.100
# step 4234, loss 0.074
# step 4235, loss 0.009
# step 4236, loss 0.026
# step 4237, loss 0.011
# step 4238, loss 0.012
# step 4239, loss 0.048
# step 4240, loss 0.016
# step 4241, loss 0.034
# step 4242, loss 0.002
# step 4243, loss 0.030
# step 4244, loss 0.013
# step 4245, loss 0.090
# step 4246, loss 0.016
# step 4247, loss 0.003
# step 4248, loss 0.009
# step 4249, loss 0.008
# step 4250, loss 0.124
# step 4251, loss 0.020
# step 4252, loss 0.002
# step 4253, loss 0.047
# step 4254, loss 0.039
# step 4255, loss 0.009
# step 4256, loss 0.014
# step 4257, loss 0.022
# step 4258, loss 0.005
# step 4259, loss 0.048
# step 4260, loss 0.002
# step 4261, loss 0.039
# step 4262, loss 0.003
# step 4263, loss 0.053
# step 4264, loss 0.027
# step 4265, loss 0.068
# step 4266, loss 0.055
# step 4267, loss 0.004
# step 4268, loss 0.004
# step 4269, loss 0.003
# step 4270, loss 0.002
# step 4271, loss 0.022
# step 4272, loss 0.003
# step 4273, loss 0.010
# step 4274, loss 0.061
# step 4275, loss 0.032
# step 4276, loss 0.071
# step 4277, loss 0.008
# step 4278, loss 0.002
# step 4279, loss 0.008
# step 4280, loss 0.014
# step 4281, loss 0.020
# step 4282, loss 0.017
# step 4283, loss 0.025
# step 4284, loss 0.026
# step 4285, loss 0.018
# step 4286, loss 0.053
# step 4287, loss 0.002
# step 4288, loss 0.085
# step 4289, loss 0.034
# step 4290, loss 0.019
# step 4291, loss 0.055
# step 4292, loss 0.002
# step 4293, loss 0.016
# step 4294, loss 0.009
# step 4295, loss 0.015
# step 4296, loss 0.004
# step 4297, loss 0.017
# step 4298, loss 0.017
# step 4299, loss 0.006
# step 4300, loss 0.008
# step 4301, loss 0.010
# step 4302, loss 0.040
# step 4303, loss 0.008
# step 4304, loss 0.023
# step 4305, loss 0.006
# step 4306, loss 0.022
# step 4307, loss 0.003
# step 4308, loss 0.040
# step 4309, loss 0.014
# step 4310, loss 0.009
# step 4311, loss 0.015
# step 4312, loss 0.006
# step 4313, loss 0.007
# step 4314, loss 0.004
# step 4315, loss 0.039
# step 4316, loss 0.004
# step 4317, loss 0.026
# step 4318, loss 0.012
# step 4319, loss 0.008
# step 4320, loss 0.014
# step 4321, loss 0.009
# step 4322, loss 0.003
# step 4323, loss 0.012
# step 4324, loss 0.002
# step 4325, loss 0.006
# step 4326, loss 0.010
# step 4327, loss 0.010
# step 4328, loss 0.005
# step 4329, loss 0.003
# step 4330, loss 0.036
# step 4331, loss 0.001
# step 4332, loss 0.007
# step 4333, loss 0.017
# step 4334, loss 0.026
# step 4335, loss 0.002
# step 4336, loss 0.008
# step 4337, loss 0.031
# step 4338, loss 0.002
# step 4339, loss 0.033
# step 4340, loss 0.004
# step 4341, loss 0.013
# step 4342, loss 0.001
# step 4343, loss 0.027
# step 4344, loss 0.016
# step 4345, loss 0.032
# step 4346, loss 0.003
# step 4347, loss 0.061
# step 4348, loss 0.002
# step 4349, loss 0.008
# step 4350, loss 0.002
# step 4351, loss 0.010
# step 4352, loss 0.002
# step 4353, loss 0.004
# step 4354, loss 0.001
# step 4355, loss 0.006
# step 4356, loss 0.082
# step 4357, loss 0.018
# step 4358, loss 0.042
# step 4359, loss 0.025
# step 4360, loss 0.001
# step 4361, loss 0.001
# step 4362, loss 0.006
# step 4363, loss 0.007
# step 4364, loss 0.002
# step 4365, loss 0.002
# step 4366, loss 0.026
# step 4367, loss 0.007
# step 4368, loss 0.002
# step 4369, loss 0.031
# step 4370, loss 0.001
# step 4371, loss 0.013
# step 4372, loss 0.001
# step 4373, loss 0.003
# step 4374, loss 0.003
# step 4375, loss 0.061
# step 4376, loss 0.040
# step 4377, loss 0.007
# step 4378, loss 0.002
# step 4379, loss 0.010
# step 4380, loss 0.029
# step 4381, loss 0.016
# step 4382, loss 0.008
# step 4383, loss 0.003
# step 4384, loss 0.087
# step 4385, loss 0.037
# step 4386, loss 0.019
# step 4387, loss 0.014
# step 4388, loss 0.029
# step 4389, loss 0.023
# step 4390, loss 0.004
# step 4391, loss 0.017
# step 4392, loss 0.003
# step 4393, loss 0.001
# step 4394, loss 0.009
# step 4395, loss 0.052
# step 4396, loss 0.004
# step 4397, loss 0.007
# step 4398, loss 0.007
# step 4399, loss 0.049
# step 4400, loss 0.002
# step 4401, loss 0.057
# step 4402, loss 0.031
# step 4403, loss 0.065
# step 4404, loss 0.005
# step 4405, loss 0.002
# step 4406, loss 0.042
# step 4407, loss 0.050
# step 4408, loss 0.014
# step 4409, loss 0.018
# step 4410, loss 0.001
# step 4411, loss 0.003
# step 4412, loss 0.024
# step 4413, loss 0.014
# step 4414, loss 0.008
# step 4415, loss 0.002
# step 4416, loss 0.001
# step 4417, loss 0.002
# step 4418, loss 0.026
# step 4419, loss 0.008
# step 4420, loss 0.002
# step 4421, loss 0.015
# step 4422, loss 0.005
# step 4423, loss 0.003
# step 4424, loss 0.021
# step 4425, loss 0.006
# step 4426, loss 0.024
# step 4427, loss 0.003
# step 4428, loss 0.030
# step 4429, loss 0.015
# step 4430, loss 0.055
# step 4431, loss 0.059
# step 4432, loss 0.008
# step 4433, loss 0.007
# step 4434, loss 0.015
# step 4435, loss 0.059
# step 4436, loss 0.001
# step 4437, loss 0.007
# step 4438, loss 0.045
# step 4439, loss 0.076
# step 4440, loss 0.008
# step 4441, loss 0.056
# step 4442, loss 0.068
# step 4443, loss 0.068
# step 4444, loss 0.007
# step 4445, loss 0.071
# step 4446, loss 0.098
# step 4447, loss 0.034
# step 4448, loss 0.085
# step 4449, loss 0.053
# step 4450, loss 0.029
# step 4451, loss 0.025
# step 4452, loss 0.029
# step 4453, loss 0.040
# step 4454, loss 0.053
# step 4455, loss 0.015
# step 4456, loss 0.047
# step 4457, loss 0.008
# step 4458, loss 0.043
# step 4459, loss 0.009
# step 4460, loss 0.013
# step 4461, loss 0.020
# step 4462, loss 0.011
# step 4463, loss 0.023
# step 4464, loss 0.030
# step 4465, loss 0.033
# step 4466, loss 0.010
# step 4467, loss 0.060
# step 4468, loss 0.002
# step 4469, loss 0.007
# step 4470, loss 0.039
# step 4471, loss 0.033
# step 4472, loss 0.045
# step 4473, loss 0.040
# step 4474, loss 0.062
# step 4475, loss 0.043
# step 4476, loss 0.003
# step 4477, loss 0.010
# step 4478, loss 0.026
# step 4479, loss 0.024
# step 4480, loss 0.008
# step 4481, loss 0.025
# step 4482, loss 0.002
# step 4483, loss 0.013
# step 4484, loss 0.017
# step 4485, loss 0.094
# step 4486, loss 0.008
# step 4487, loss 0.086
# step 4488, loss 0.007
# step 4489, loss 0.035
# step 4490, loss 0.043
# step 4491, loss 0.012
# step 4492, loss 0.013
# step 4493, loss 0.007
# step 4494, loss 0.003
# step 4495, loss 0.066
# step 4496, loss 0.026
# step 4497, loss 0.048
# step 4498, loss 0.017
# step 4499, loss 0.007
# step 4500, loss 0.005
# step 4501, loss 0.004
# step 4502, loss 0.003
# step 4503, loss 0.040
# step 4504, loss 0.048
# step 4505, loss 0.010
# step 4506, loss 0.006
# step 4507, loss 0.032
# step 4508, loss 0.015
# step 4509, loss 0.004
# step 4510, loss 0.002
# step 4511, loss 0.033
# step 4512, loss 0.012
# step 4513, loss 0.043
# step 4514, loss 0.004
# step 4515, loss 0.054
# step 4516, loss 0.002
# step 4517, loss 0.004
# step 4518, loss 0.013
# step 4519, loss 0.002
# step 4520, loss 0.040
# step 4521, loss 0.003
# step 4522, loss 0.023
# step 4523, loss 0.100
# step 4524, loss 0.041
# step 4525, loss 0.031
# step 4526, loss 0.008
# step 4527, loss 0.027
# step 4528, loss 0.038
# step 4529, loss 0.001
# step 4530, loss 0.002
# step 4531, loss 0.055
# step 4532, loss 0.023
# step 4533, loss 0.032
# step 4534, loss 0.009
# step 4535, loss 0.003
# step 4536, loss 0.033
# step 4537, loss 0.040
# step 4538, loss 0.095
# step 4539, loss 0.032
# step 4540, loss 0.005
# step 4541, loss 0.025
# step 4542, loss 0.007
# step 4543, loss 0.002
# step 4544, loss 0.004
# step 4545, loss 0.065
# step 4546, loss 0.043
# step 4547, loss 0.097
# step 4548, loss 0.023
# step 4549, loss 0.038
# step 4550, loss 0.018
# step 4551, loss 0.002
# step 4552, loss 0.004
# step 4553, loss 0.054
# step 4554, loss 0.046
# step 4555, loss 0.014
# step 4556, loss 0.002
# step 4557, loss 0.122
# step 4558, loss 0.021
# step 4559, loss 0.002
# step 4560, loss 0.013
# step 4561, loss 0.014
# step 4562, loss 0.026
# step 4563, loss 0.007
# step 4564, loss 0.051
# step 4565, loss 0.001
# step 4566, loss 0.036
# step 4567, loss 0.007
# step 4568, loss 0.083
# step 4569, loss 0.010
# step 4570, loss 0.049
# step 4571, loss 0.001
# step 4572, loss 0.099
# step 4573, loss 0.012
# step 4574, loss 0.017
# step 4575, loss 0.002
# step 4576, loss 0.008
# step 4577, loss 0.065
# step 4578, loss 0.002
# step 4579, loss 0.004
# step 4580, loss 0.002
# step 4581, loss 0.007
# step 4582, loss 0.008
# step 4583, loss 0.002
# step 4584, loss 0.006
# step 4585, loss 0.070
# step 4586, loss 0.023
# step 4587, loss 0.003
# step 4588, loss 0.012
# step 4589, loss 0.018
# step 4590, loss 0.004
# step 4591, loss 0.007
# step 4592, loss 0.002
# step 4593, loss 0.016
# step 4594, loss 0.043
# step 4595, loss 0.008
# step 4596, loss 0.004
# step 4597, loss 0.007
# step 4598, loss 0.006
# step 4599, loss 0.027
# step 4600, loss 0.024
# step 4601, loss 0.004
# step 4602, loss 0.077
# step 4603, loss 0.026
# step 4604, loss 0.022
# step 4605, loss 0.008
# step 4606, loss 0.001
# step 4607, loss 0.034
# step 4608, loss 0.002
# step 4609, loss 0.036
# step 4610, loss 0.002
# step 4611, loss 0.023
# step 4612, loss 0.052
# step 4613, loss 0.007
# step 4614, loss 0.004
# step 4615, loss 0.026
# step 4616, loss 0.003
# step 4617, loss 0.004
# step 4618, loss 0.006
# step 4619, loss 0.001
# step 4620, loss 0.015
# step 4621, loss 0.008
# step 4622, loss 0.038
# step 4623, loss 0.012
# step 4624, loss 0.021
# step 4625, loss 0.001
# step 4626, loss 0.005
# step 4627, loss 0.026
# step 4628, loss 0.005
# step 4629, loss 0.022
# step 4630, loss 0.054
# step 4631, loss 0.001
# step 4632, loss 0.004
# step 4633, loss 0.004
# step 4634, loss 0.015
# step 4635, loss 0.006
# step 4636, loss 0.046
# step 4637, loss 0.003
# step 4638, loss 0.016
# step 4639, loss 0.007
# step 4640, loss 0.010
# step 4641, loss 0.002
# step 4642, loss 0.007
# step 4643, loss 0.042
# step 4644, loss 0.045
# step 4645, loss 0.039
# step 4646, loss 0.001
# step 4647, loss 0.005
# step 4648, loss 0.011
# step 4649, loss 0.037
# step 4650, loss 0.014
# step 4651, loss 0.011
# step 4652, loss 0.004
# step 4653, loss 0.004
# step 4654, loss 0.004
# step 4655, loss 0.019
# step 4656, loss 0.032
# step 4657, loss 0.004
# step 4658, loss 0.025
# step 4659, loss 0.005
# step 4660, loss 0.001
# step 4661, loss 0.003
# step 4662, loss 0.001
# step 4663, loss 0.001
# step 4664, loss 0.053
# step 4665, loss 0.035
# step 4666, loss 0.007
# step 4667, loss 0.002
# step 4668, loss 0.007
# step 4669, loss 0.046
# step 4670, loss 0.010
# step 4671, loss 0.063
# step 4672, loss 0.013
# step 4673, loss 0.008
# step 4674, loss 0.002
# step 4675, loss 0.001
# step 4676, loss 0.004
# step 4677, loss 0.014
# step 4678, loss 0.033
# step 4679, loss 0.002
# step 4680, loss 0.050
# step 4681, loss 0.026
# step 4682, loss 0.004
# step 4683, loss 0.002
# step 4684, loss 0.007
# step 4685, loss 0.005
# step 4686, loss 0.043
# step 4687, loss 0.012
# step 4688, loss 0.055
# step 4689, loss 0.006
# step 4690, loss 0.002
# step 4691, loss 0.002
# step 4692, loss 0.003
# step 4693, loss 0.006
# step 4694, loss 0.002
# step 4695, loss 0.019
# step 4696, loss 0.004
# step 4697, loss 0.019
# step 4698, loss 0.010
# step 4699, loss 0.022
# step 4700, loss 0.006
# step 4701, loss 0.075
# step 4702, loss 0.053
# step 4703, loss 0.030
# step 4704, loss 0.003
# step 4705, loss 0.014
# step 4706, loss 0.001
# step 4707, loss 0.001
# step 4708, loss 0.006
# step 4709, loss 0.001
# step 4710, loss 0.019
# step 4711, loss 0.002
# step 4712, loss 0.001
# step 4713, loss 0.004
# step 4714, loss 0.002
# step 4715, loss 0.018
# step 4716, loss 0.021
# step 4717, loss 0.006
# step 4718, loss 0.001
# step 4719, loss 0.007
# step 4720, loss 0.001
# step 4721, loss 0.001
# step 4722, loss 0.050
# step 4723, loss 0.002
# step 4724, loss 0.007
# step 4725, loss 0.024

# %%
final_labels = []
def test(model):
    model.eval()
    test_loader = build_batch(word2id_dict, test_corpus, batch_size, epoch_num, max_seq_len, train=False)
    for step, (sentences) in enumerate(test_loader):
        sentences = paddle.to_tensor(sentences)
        logits = model(sentences)
        labels = fluid.layers.argmax(F.softmax(logits, dtype='float64'),axis=-1).numpy().tolist()
        final_labels.extend(labels)

# %%
test(intent_clf)

# %%
final_labels_str = []
for label in final_labels:
    for key in label_dict:
        if label_dict[key] == label:
            final_labels_str.append(key)
            break
print(len(final_labels_str))
test_data["pred_by_w2v_emb_lstm"] = final_labels_str
# Out:
# 3000

# %%
from collections import Counter
Counter(final_labels)
# Out:
# Counter({2: 444,
#          5: 216,
#          10: 204,
#          7: 253,
#          1: 252,
#          8: 220,
#          3: 301,
#          0: 220,
#          9: 192,
#          4: 286,
#          6: 242,
#          11: 170})

# %%
from collections import Counter
Counter(final_labels)
# Out:
# Counter({10: 208,
#          5: 199,
#          7: 239,
#          2: 381,
#          1: 287,
#          8: 235,
#          3: 319,
#          0: 236,
#          9: 233,
#          4: 308,
#          6: 214,
#          11: 141})

# %%
#在https://competition.coggle.club/上的结果是0.664667
#这个是随机初始化的lstm embedding
with open("results\\lstm_random_init.txt","w") as f:
    f.write("ID,Target\n")
    for i in range(len(test_data)):
        f.write(str(i+1)+","+test_data.iloc[i]["pred_by_init_emb_lstm"]+"\n")

# %%
#在https://competition.coggle.club/上的结果是0.784000
#这个是使用开源w2v初始化的lstm embedding
with open("results\\lstm_w2v_init.txt","w") as f:
    f.write("ID,Target\n")
    for i in range(len(test_data)):
        f.write(str(i+1)+","+test_data.iloc[i]["pred_by_w2v_emb_lstm"]+"\n")

# %%
#经过试验得出结论：
#1.Embedding层的精度与初始化方式相关吗？是相关的，如果随机初始化的结果远低于使用一个好的w2v作为初始化的结果
#2.LSTM模型精度与文本最大长度是否相关？根据数据分析得知，该数据集文本的最大长度是31个分词，因此如果文本最大长度取得比较大（比如128），那么导致整条文本大部分是pad,
# 这就会很影响最终的结果，但是把最大长度调整成32之后，最终的效果就提升很多。
